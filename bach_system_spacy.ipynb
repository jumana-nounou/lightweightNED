# %% [markdown]
# <a href="https://colab.research.google.com/github/jumana-nounou/lightweightNED/blob/main/bach_system_spacy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Installation

# %%
# !pip install transformers
# !git clone https://github.com/aub-mind/arabert
# !pip install pyarabic
# !pip install farasapy
# !pip install sentencepiece
# !pip install sacremoses
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)
# fatal: destination path 'arabert' already exists and is not an empty directory.
# Requirement already satisfied: pyarabic in /usr/local/lib/python3.10/dist-packages (0.6.15)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from pyarabic) (1.16.0)
# Requirement already satisfied: farasapy in /usr/local/lib/python3.10/dist-packages (0.0.14)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from farasapy) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from farasapy) (4.66.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->farasapy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->farasapy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->farasapy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->farasapy) (2023.11.17)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.1.99)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.10/dist-packages (0.1.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacremoses) (2023.6.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from sacremoses) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from sacremoses) (1.3.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sacremoses) (4.66.1)

# %% [markdown]
# ## Imports

# %%
import json
from sklearn.preprocessing import LabelEncoder
from transformers import AutoTokenizer, AutoModel
# from preprocess import NEVER_SPLIT_TOKENS,ArabertPreprocessor
from arabert.preprocess import NEVER_SPLIT_TOKENS,ArabertPreprocessor
from farasa.segmenter import FarasaSegmenter
import torch
import requests
from transformers import MBartForConditionalGeneration, MBart50Tokenizer
from transformers import AutoModelForTokenClassification
import re
from collections import defaultdict
from sklearn.metrics.pairwise import cosine_similarity
from pyarabic.araby import tokenize
from transformers import MarianMTModel, MarianTokenizer
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
import torch.nn.functional as F
import numpy as np
import spacy

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.insert(0,'/content/arabert')
print(sys.path)
# Out:
# ['/content/arabert', '/content/arabert', '/content', '/env/python', '/usr/lib/python310.zip', '/usr/lib/python3.10', '/usr/lib/python3.10/lib-dynload', '', '/usr/local/lib/python3.10/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.10/dist-packages/IPython/extensions', '/root/.ipython']

# %%
# !ls /content/arabert
# Out:
# arabert		  AraELECTRA.png  examples	 __pycache__	   setup.py
# arabert_logo.png  aragpt2	  __init__.py	 README.md
# araelectra	  AraGPT2.png	  preprocess.py  requirements.txt

# %% [markdown]
# ## Paths

# %%
train_file_path = '/content/drive/MyDrive/Dataset/train.txt'
test_file_path = '/content/drive/MyDrive/Dataset/test.txt'
# val_file_path = '/content/drive/MyDrive/Bachelor/NER/val.txt'

# %% [markdown]
# ## Functions

# %% [markdown]
# Data Cleaning functions

# %%
def read_file_with_sentences(file_path):
    data = []
    current_sentence = []
    current_sentence_text = []  # Store the text of the current sentence

    with open(file_path, 'r', encoding='utf-8') as file:
        word_index = 0  # Initialize word index counter
        for line in file:
            line = line.strip()
            if line:
                last_space_index = line.rfind(' ')
                text = line[:last_space_index]
                label = line[last_space_index + 1:]
                current_sentence.append({'word': text.strip(), 'tag': label, 'word_index': word_index})  # Include word index
                current_sentence_text.append(text)  # Collect the text of the word
                word_index += 1  # Increment word index
            else:
                if current_sentence:
                    # Append each word, its tag, and the sentence it belongs to as a dictionary
                    sentence_text = ' '.join(current_sentence_text).replace('O', '')
                    for word_info in current_sentence:
                        word_info['sentence'] = sentence_text
                    data.extend(current_sentence)
                    current_sentence = []
                    current_sentence_text = []  # Reset the text of the sentence
                    word_index = 0  # Reset word index for the next sentence

    return data

# %%
def combine_phrases(data):
    combined_data = []
    current_phrase = {'word': '', 'tag': '', 'sentence': '','word_index':''}

    for entry in data:
        if entry['tag'].startswith('B-'):  # Beginning of a new phrase
            if current_phrase['word']:
                combined_data.append(current_phrase.copy())
                current_phrase = {'word': '', 'tag': '', 'sentence': '','word_index':''}

            current_phrase['word'] += entry['word'] + ' '
            current_phrase['tag'] = entry['tag'][2:]  # Remove 'B-' from the tag
            current_phrase['sentence'] = entry['sentence']
            current_phrase['word_index'] = entry['word_index']
        elif entry['tag'].startswith('I-'):  # Inside a phrase
            current_phrase['word'] += entry['word'] + ' '
        else:  # Outside a phrase
            if current_phrase['word']:
                combined_data.append(current_phrase.copy())
                current_phrase = {'word': '', 'tag': '', 'sentence': '','word_index':''}

    # Append the last phrase if present
    if current_phrase['word']:
        combined_data.append(current_phrase)

    return combined_data

# %%
def filter_non_O_tags(data):
    filtered_data = [point for point in data if point.get('tag') != 'O']
    return filtered_data

# %%
def remove_preposition(word):
    prepositions = ["و","ب", "ك", "ل", "ف"]
    if word[0] in prepositions:
        return word[1:]
    else:
        return word

# %% [markdown]
# Wikidata retrieval

# %%
def get_wikidata_candidates(entity):
    url = f"https://www.wikidata.org/w/api.php?action=wbsearchentities&search={entity}&language=ar&format=json"
    response = requests.get(url)
    data = response.json()

    candidates = []
    if data.get('search'):
        candidates = [result['id'] for result in data['search']]
    else:
        # Translate the word to English and try getting candidates
        translated_word = translate_to_english(entity)
        if translated_word:
            url = f"https://www.wikidata.org/w/api.php?action=wbsearchentities&search={translated_word}&language=en&format=json"
            response = requests.get(url)
            data = response.json()
            if data.get('search'):
                candidates = [result['id'] for result in data['search']]
            else:
                # If still no candidates, try removing prepositions and get candidates
                updated_word = remove_preposition(entity)
                url = f"https://www.wikidata.org/w/api.php?action=wbsearchentities&search={updated_word}&language=ar&format=json"
                response = requests.get(url)
                data = response.json()
                if data.get('search'):
                    candidates = [result['id'] for result in data['search']]

    return candidates

# %%
def get_claim_value(claim):
    mainsnak = claim.get('mainsnak', {})
    datavalue = mainsnak.get('datavalue', {})
    value = datavalue.get('value', {})
    if 'id' in value:
        return value['id']
    elif 'time' in value:
        return value['time']
    return str(value)

def get_entity_labels(entity_ids):
    entity_labels = {}
    url = "https://www.wikidata.org/w/api.php"
    params = {
        "action": "wbgetentities",
        "ids": "|".join(entity_ids),
        "props": "labels",
        "languages": "ar|en",  # Prioritize Arabic then English
        "format": "json"
    }
    response = requests.get(url, params=params)
    data = response.json()
    if 'entities' in data:
        for entity_id, entity_info in data['entities'].items():
            # Prioritize Arabic labels, if available
            label = entity_info['labels']['ar']['value'] if 'ar' in entity_info['labels'] else ''
            # If Arabic label is not available, use English label
            if not label and 'en' in entity_info['labels']:
                label = translate_to_arabic(entity_info['labels']['en']['value'])
            entity_labels[entity_id] = label
    return entity_labels

def get_labels_of_entities(entity_ids):
    entity_labels = get_entity_labels(entity_ids)
    return [entity_labels.get(entity_id, '') for entity_id in entity_ids]

def get_entity_data(entity_id):
    url = f"https://www.wikidata.org/wiki/Special:EntityData/{entity_id}.json"
    response = requests.get(url)
    data = response.json()

    if 'entities' in data and entity_id in data['entities']:
        entity_data = data['entities'][entity_id]
        label_en = entity_data['labels'].get('en', {}).get('value', 'Label not found')
        label_ar = entity_data['labels'].get('ar', {}).get('value', '')
        label = label_ar if label_ar else translate_to_arabic(label_en)

        entity_description_en = entity_data['descriptions'].get('en', {}).get('value', 'Description not found')
        entity_description_ar = entity_data['descriptions'].get('ar', {}).get('value', '')
        description = entity_description_ar if entity_description_ar else translate_to_arabic(entity_description_en)

        claims = entity_data.get('claims', {})
        relevant_properties = {
            'instance of': 'P31',
            'المهنة': 'P106',
            'فئة فرعية من': 'P279',
            'لديه جزء': 'P527',
            'جزء من': 'P361',
            'تقع في': 'P131',
            'البلد': 'P17',
            'رمز العملة': 'P478',
            'رمز العملة': 'P506',
            'فئة': 'P3961',
            'تاريخ التأسيس': 'P571',
            'موقع المقر': 'P159',
            'legal form': 'P1454',
            'key people': 'P3320',        }

        properties_description = []
        occupation_entity_ids = []
        instance_label = ''

        for prop_label, prop_id in relevant_properties.items():
            if prop_id in claims and prop_label != 'instance of':  # Exclude 'instance of' from description
                prop_values = [get_claim_value(claim) for claim in claims[prop_id]]
                if prop_label == 'occupation':
                    occupation_entity_ids.extend(prop_values)
                # Fetch the labels of entities instead of their IDs
                prop_labels = get_labels_of_entities([str(entity_id) for entity_id in prop_values])
                properties_description.append(f"{prop_label}: {', '.join(prop_labels)}")

        occupation_labels = {}
        if occupation_entity_ids:
            occupation_labels = get_entity_labels([str(entity_id) for entity_id in occupation_entity_ids])

        for idx, prop_value in enumerate(properties_description):
            if prop_value.startswith('occupation'):
                occupation_entities = prop_value.split(' ')[1].split(' ')
                occupation_labels_str = ', '.join(occupation_labels.get(occ_entity, occ_entity) for occ_entity in occupation_entities)
                properties_description[idx] = f"occupation: {occupation_labels_str}"

        entity_description = f"{label} {description}"
        entity_description += ' '.join(properties_description)

        instance_of = claims.get('P31', [])
        instance_values = [get_claim_value(instance) for instance in instance_of]
        if 'Q5' in instance_values:  # Q5 represents human
            instance_label = "PERS"
        elif 'Q11424' in instance_values:  # Q11424 represents film
            instance_label = "MISC"
        elif 'Q2221906' in instance_values:  # Q2221906 represents geographical location
            instance_label = "LOC"
        elif 'Q4917' in instance_values:  # Q4917 represents currency
            instance_label = "MISC"
        elif 'Q43229' in instance_values:  # Q43229 represents organization
            instance_label = "ORG"

        return {
            'entity_ID':entity_id,
            'entity_label': label,
            'description': entity_description,
            'instance_label': instance_label
        }
    else:
        return {
            'entity_ID':entity_id,
            'entity_label': '',
            'description': "Entity not found in Wikidata",
            'instance_label': ''
        }

# %%
def translate_to_arabic(text_to_translate):
    # Load the English to Arabic translation model and tokenizer
    model_name = "Helsinki-NLP/opus-mt-en-ar"
    tokenizer = MarianTokenizer.from_pretrained(model_name)
    model = MarianMTModel.from_pretrained(model_name)

    # Tokenize the text
    inputs = tokenizer(text_to_translate, return_tensors="pt", padding=True, truncation=False)

    # Translate the text
    translated = model.generate(**inputs, max_length=128, num_beams=4, early_stopping=True)

    # Decode the translated text
    translated_text = tokenizer.decode(translated[0], skip_special_tokens=True)

    return translated_text

# %%
def generate_candidates_and_get_their_data(data_structure):
    for entry in data_structure:
        word = entry['word']
        candidates = get_wikidata_candidates(word)
        entry['candidates'] = []

        for candidate in candidates:
            entity_data = get_entity_data(candidate)
            if entity_data:
                label_value = entity_data['entity_label']
                description_value = entity_data['description']
                ner_tag = entity_data['instance_label']

                entry['candidates'].append({
                    'entity': candidate,
                    'label': label_value,
                    'description': description_value,
                    'ner_tag': ner_tag if ner_tag else None  # Keep None for missing ner_tag
                })

        # Handle missing or empty ner_tag using ner_for_entities_with_candidates
        missing_ner_candidates = [c for c in entry['candidates'] if not c.get('ner_tag')]
        if missing_ner_candidates:
            updated_candidates = ner_for_entities_with_candidates([{'word': word, 'candidates': missing_ner_candidates}])
            for index, updated_candidate in enumerate(updated_candidates[0]['candidates']):
                entry['candidates'][index]['ner_tag'] = updated_candidate['ner_tag']

    return data_structure

# %%
def translate_to_english(text_to_translate):
    # Load the Arabic to English translation model and tokenizer
    model_name = "Helsinki-NLP/opus-mt-ar-en"
    tokenizer = MarianTokenizer.from_pretrained(model_name)
    model = MarianMTModel.from_pretrained(model_name)

    # Tokenize the text
    inputs = tokenizer(text_to_translate, return_tensors="pt", padding=True, truncation=True)

    # Translate the text
    translated = model.generate(**inputs, max_length=128, num_beams=4, early_stopping=True)

    # Decode the translated text
    translated_text = tokenizer.decode(translated[0], skip_special_tokens=True)

    return translated_text

# %%
def map_spacy_labels(entity_label):
    if entity_label == "PERSON":
        return "PERS"
    elif entity_label == "GPE":
        return "LOC"
    elif entity_label == "ORG":
        return "ORG"
    else:
        return "MISC"

def ner_for_entities_with_candidates(input_data):
    nlp = spacy.load("en_core_web_sm")

    for item in input_data:
        word = item['word']
        candidates = item['candidates']

        for candidate in candidates:
            label = candidate['label']
            description = candidate['description']
            combined_text = f"{label} is {description}"

            # Translate combined text to English
            translated_text = translate_to_english(combined_text)

            # Process the translated text with spaCy for NER
            doc = nlp(translated_text)

            # Access named entities and their labels and normalize them
            ner_tag = None
            for ent in doc.ents:
                ner_tag = map_spacy_labels(ent.label_)
                break  # Take the first entity label found

            candidate['ner_tag'] = ner_tag

    return input_data

# %% [markdown]
# Embeddings

# %%
def get_word_embeddings_arabert(word, sentence):
    # Tokenize the sentence and word separately
    sentence_tokens = tokenizer.encode_plus(sentence, return_tensors='pt', max_length=32, truncation=True, padding=True)
    word_tokens = tokenizer.encode_plus(word, return_tensors='pt', max_length=32, truncation=True, padding=True)

    combined_tokens = {
        'input_ids': torch.cat((sentence_tokens['input_ids'], word_tokens['input_ids']), dim=1),
        'attention_mask': torch.cat((sentence_tokens['attention_mask'], word_tokens['attention_mask']), dim=1)
    }

    with torch.no_grad():
        output = model(**combined_tokens)
        embeddings = output.last_hidden_state.mean(dim=1)

    word_embeddings = embeddings[:, sentence_tokens.input_ids.size(1):].squeeze()

    return word_embeddings

# %%
def generate_contextual_embeddings(sentence):
    tokens = tokenizer.encode_plus(sentence, return_tensors='pt', max_length=128, truncation=True, padding=True)

    with torch.no_grad():
        outputs = model(**tokens)
        contextual_embeddings = outputs.last_hidden_state.mean(dim=1)

    return contextual_embeddings.squeeze()

# %% [markdown]
# Disambiguation

# %%
def get_results_of_disambiguation(entity_id):
    if not entity_id:
        return None, None

    wikidata_api_url = f"https://www.wikidata.org/w/api.php?action=wbgetentities&ids={entity_id}&format=json"
    response = requests.get(wikidata_api_url)

    if response.status_code == 200:
        data = response.json()
        entity_data = data['entities'].get(entity_id)
        if entity_data:
            label = entity_data.get('labels', {}).get('en', {}).get('value')
            description = entity_data.get('descriptions', {}).get('en', {}).get('value')
            return label, description
        else:
            return None, None
    else:
        return None, None

# %%
def calculate_similarity(embedding_a, embedding_b):
    if embedding_a is None or embedding_b is None or embedding_a.size(0) == 0 or embedding_b.size(0) == 0:
        return 0.0

    # Assuming embeddings are torch tensors
    if embedding_a.dim() == 1:
        embedding_a = embedding_a.unsqueeze(0)
    if embedding_b.dim() == 1:
        embedding_b = embedding_b.unsqueeze(0)

    # Printing dimensions before reshaping
    # print(f"Original Embedding A shape: {embedding_a.shape}")
    # print(f"Original Embedding B shape: {embedding_b.shape}")

    # Reshaping embeddings if necessary
    if embedding_a.dim() == 2 and embedding_b.dim() == 2:
        if embedding_a.size(1) != embedding_b.size(1):
            # Reshape embedding_b to match the second dimension of embedding_a (e.g., 768)
            desired_shape = (embedding_b.size(0), embedding_a.size(1))  # Get the desired shape
            if embedding_b.size(1) < embedding_a.size(1):
                # If embedding_b has fewer dimensions, pad with zeros
                pad_width = embedding_a.size(1) - embedding_b.size(1)
                embedding_b = torch.tensor(np.pad(embedding_b.numpy(), ((0, 0), (0, pad_width)), mode='constant'))
            else:
                # If embedding_b has more dimensions, truncate to match embedding_a's dimension
                embedding_b = embedding_b[:, :embedding_a.size(1)]

    try:
        # Calculating similarity using cosine similarity without normalization
        similarity_score = cosine_similarity(embedding_a.detach().numpy(), embedding_b.detach().numpy())[0][0]
        return similarity_score  # Return the calculated similarity score

    except Exception as e:
        print(f"Error occurred: {e}")
        return 0.0  # Return default score in case of error

# %%
def disambiguation_function(input_data, threshold=0.05, weight_threshold=0.01):
    result_entities = []

    for data_element in input_data:
        best_entity = "Entity not found"
        best_label = "Label not found"
        best_tag = ""
        best_description = "Description not found"
        max_combined_score = -1
        second_best_score = -1
        other_entities = []

        word_embedding = data_element.get('word_embedding')
        sentence_embedding = data_element.get('sentence_embedding')
        candidates = data_element.get('candidates')

        if word_embedding is not None and sentence_embedding is not None and candidates:
            candidates = [candidate for candidate in candidates if
                          candidate.get('label_embedding') is not None and candidate.get('description_embedding') is not None]

            entity_found = False

            for candidate in candidates:
                label_embedding = candidate.get('label_embedding')
                description_embedding = candidate.get('description_embedding')

                sentence_desc_similarity = calculate_similarity(sentence_embedding, description_embedding)

                window_size = 3

                try:
                    word_index = int(data_element.get('word_index', 0))
                except ValueError:
                    # Handle the case when the value cannot be converted to an integer
                    # Set a default value (0 or 1 in this case)
                    word_index = 0  # Change this to 1 if needed

                context_start = max(0, word_index - window_size)
                context_end = min(len(sentence_embedding), word_index + window_size + 1)
                context_embedding = sentence_embedding[context_start:context_end]

                label_word_similarity = calculate_similarity(word_embedding, context_embedding)

                context_desc_similarity = calculate_similarity(context_embedding, description_embedding)

                word_ner_tag = data_element.get('tag')
                candidate_ner_tag = candidate.get('ner_tag')

                ner_similarity = 0.0
                if word_ner_tag and candidate_ner_tag and word_ner_tag == candidate_ner_tag:
                    ner_similarity = 0.3

                combined_score = (0.4 * sentence_desc_similarity) + (
                        0.3 * context_desc_similarity) + (0.3 * label_word_similarity) + ner_similarity

                # Store entity details in other_entities
                other_entities.append({
                    'entity': candidate['entity'],
                    'label': candidate['label'],
                    'description': candidate['description'],
                    'sentence_desc_similarity': sentence_desc_similarity,
                    'context_desc_similarity': context_desc_similarity,
                    'ner_tag': candidate.get('ner_tag', '')
                })

                if combined_score > max_combined_score:
                    second_best_score = max_combined_score
                    max_combined_score = combined_score
                    best_entity = candidate['entity']
                    best_label = candidate['label']
                    best_description = candidate['description']
                    best_tag = candidate_ner_tag
                    entity_found = True

                elif combined_score > second_best_score:
                    second_best_score = combined_score

            if not entity_found:
                continue

            # Normalizing scores
            max_combined_score -= second_best_score
            second_best_score = 0

            if abs(max_combined_score) > 0:
                max_combined_score /= max_combined_score

            if abs(second_best_score) > 0:
                second_best_score /= second_best_score

            if abs(max_combined_score - second_best_score) <= threshold:
                # Further validation based on contextual and NER similarities
                if len(other_entities) >= 2:
                    contextual_similarity_difference = abs(
                        (other_entities[0]['context_desc_similarity']) - (other_entities[1]['context_desc_similarity'])
                    )

                    word_ner_tag = data_element.get('tag')

                    if (contextual_similarity_difference > weight_threshold):
                        best_entity = other_entities[1]['entity']
                        best_label = other_entities[1]['label']
                        best_description = other_entities[1]['description']
                    elif (
                        (contextual_similarity_difference <= weight_threshold)
                        and (word_ner_tag == other_entities[1]['ner_tag'])  # Check NER match with second best entity
                    ):
                        best_entity = other_entities[1]['entity']
                        best_label = other_entities[1]['label']
                        best_description = other_entities[1]['description']
                    elif (
                        (word_ner_tag == other_entities[0]['ner_tag'])
                        or (word_ner_tag == other_entities[1]['ner_tag'])
                    ):
                        best_entity = other_entities[0]['entity'] if word_ner_tag == other_entities[0]['ner_tag'] else other_entities[1]['entity']
                        best_label = other_entities[0]['label'] if word_ner_tag == other_entities[0]['ner_tag'] else other_entities[1]['label']
                        best_description = other_entities[0]['description'] if word_ner_tag == other_entities[0]['ner_tag'] else other_entities[1]['description']
                    else:
                        best_entity = other_entities[0]['entity'] if max_combined_score > second_best_score else other_entities[1]['entity']
                        best_label = other_entities[0]['label'] if max_combined_score > second_best_score else other_entities[1]['label']
                        best_description = other_entities[0]['description'] if max_combined_score > second_best_score else other_entities[1]['description']

        other_entities = [{
            'entity': entity['entity'],
            'entity_label': entity['label'],
            'entity_description': entity['description'],
            'tag':entity['ner_tag'],
            'label':0
        } for entity in other_entities]

        result_entities.append({
            'word': data_element['word'],
            'sentence': data_element['sentence'],
            'tag': data_element['tag'],
            'correctly_labelled':1,
            'best_entity': {
                'entity': best_entity,
                'entity_label': best_label,
                'entity_description': best_description,
                'tag': best_tag,
                'label':1
            },
            'other_entities': other_entities,

        })

    return result_entities

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# First, load your dataset using the read_file_with_sentences function

# %%
train_data = read_file_with_sentences(train_file_path)
test_data = read_file_with_sentences(test_file_path)
# val_data = read_file_with_sentences(val_file_path)

# %%
test_data = combine_phrases(test_data)
train_data = combine_phrases(train_data)
train_data=train_data+test_data

# %%
train_data[79]
# Out:
# {'word': 'حزب الله ',
#  'tag': 'ORG',
#  'sentence': 'عربيا دعا الرئيس السوري بشار الأسد المجتمع الدولي إلى التحرك بسرعة لترتيب وقف لإطلاق النار ينهي الأزمة بين حزب الله وإسرائيل .',
#  'word_index': 18}

# %% [markdown]
# Data Cleaning

# %%
label_counts = defaultdict(int)

for data_point in train_data:
    if 'tag' not in data_point:
        print(f"Missing 'tag' field in data point {data_point}. Skipping...")
        continue
    label = data_point['tag']
    label_counts[label] += 1

# Get unique labels
all_labels = set(label_counts.keys())

# Print label counts and unique labels
for label, count in label_counts.items():
    print(f"Label: {label}, Count: {count}")

print("Unique Labels:", all_labels)
# Out:
# Label: LOC, Count: 4637
# Label: ORG, Count: 2543
# Label: PERS, Count: 3592
# Label: MISC, Count: 1073
# Label: , Count: 69
# Unique Labels: {'', 'MISC', 'LOC', 'PERS', 'ORG'}

# %% [markdown]
# Drop any word that has the tag O

# %%
import random

filtered_train_data = filter_non_O_tags(train_data)

subset_filtered_train_data = filtered_train_data[4000:5000]
subset_filtered_train_data = random.sample(subset_filtered_train_data, 80)

# %%
filtered_train_data[0]
# Out:
# {'word': 'فرانكفورت ',
#  'tag': 'LOC',
#  'sentence': 'فرانكفورت (د ب أ) أعلن اتحاد صناعة السيارات في ألمانيا امس الاول أن شركات صناعة السيارات في ألمانيا تواجه عاما صعبا في ظل ركود السوق الداخلية والصادرات وهي تسعي لان يبلغ الانتاج حوالي خمسة ملايين سيارة في عام 2002 .',
#  'word_index': 0}

# %% [markdown]
# ## Generating candidates

# %%
generate_candidates_and_get_their_data(subset_filtered_train_data)
# Out:
# [{'word': 'الصين ',
#   'tag': 'LOC',
#   'sentence': 'كما يتحدثون أيضاً عن أحلام للإمبراطور ومشاهدات مسئول الفلك لنجم مضيء في اتجاه الغرب , يفسّره فلكيو القصر للإمبراطور آنذاك بأنه بشارة بظهور رجل حكيم في بلاد العرب هو محمد ( صلى الله عليه وسلم ) , فيرسل الإمبراطور وفداً للرسول الجديد احتراماً وتقرّباً , حيث يعود الوفد الصيني من رحلته إلى شبه الجزيرة العربية ومعه وفد عربي من صحابة الرسول وفي مقدمتهم الصحابي الجليل سعد بن أبي وقاص كأول دخول للإسلام في الصين , إلا أن هذه الأسطورة تشبه إلى حد كبير ما جاء في الأساطير البوذية حول دخول الديانة البوذية إلى الصين من الهند .',
#   'word_index': 93,
#   'candidates': [{'entity': 'Q148',
#     'label': 'الصين',
#     'description': 'الصين دولة في شرق آسياجزء من: الصين التاريخية, شرق آسيا البلد: الصين تاريخ التأسيس: ',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q29520',
#     'label': 'الصين التاريخية',
#     'description': 'الصين التاريخية في المنطقة الثقافية، والحضارة القديمة، والأمة في شرق آسيا، تشير في معظمها إلى جمهورية الصين الشعبية في الحالة السياسية ونادراً ما تشير إلى جمهورية الصينلديه جزء: الصين, تايوان',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q1135255',
#     'label': 'جمهورية الصين السوفيتية',
#     'description': 'جمهورية الصين السوفيتية دولة سابقةتاريخ التأسيس: ',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q20420088',
#     'label': 'الصين',
#     'description': 'الصين محلة في قرية العارضة، عزلة بني شبيب، مديرية حبيش، محافظة إب اليمنيةتقع في: العارضة البلد: اليمن',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q7850',
#     'label': 'الصينية',
#     'description': 'الصينية مجموعة اللغات التي تنتمي إلى الأسرة الصينية التبتيةفئة فرعية من: لغات صينية تبتية, م لديه جزء: لغات مين الصينية, صينية يوي, لغة الهاكا, وو, الصينية المندرينية, شيانغ صيني, جين صيني, Huechs الصينية, البنغية, با - سو صيني, شاسوتشو البلد: الصين, تايوان',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q178528',
#     'label': 'حروف صينية تقليدية',
#     'description': 'حروف صينية تقليدية رموز صينية لا تزال تستخدم لأغراض رسمية في تايوان وفي هونغ كونغ وماكاو وفي أماكن أخرى بصورة غير رسميةفئة فرعية من: مقاطع صينية جزء من: الصينية التقليدية البلد: الصين, هونغ كونغ, ماكاو, تايوان, الفلبين, الولايات المتحدة, سنغافورة رمز العملة:  تاريخ التأسيس: ',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q9192',
#     'label': 'الصينية المندرينية',
#     'description': 'الصينية المندرينية فرعٌ من اللغة الصينية يتحدثها أغلب أهالي القسم الشمالي والشمالي الغربي من الصينفئة فرعية من: الصينية تقع في: هونغ كونغ, ماكاو البلد: بروناي, الصين, تايوان, إندونيسيا, ماليزيا, الفلبين, سنغافورة',
#     'ner_tag': 'MISC'}]},
#  {'word': 'سعد ابن أبي وقاص ',
#   'tag': 'PERS',
#   'sentence': 'المصادر العربية - كما يعرف القارئ - واضحة جداً حول هذا الموضوع , فالصحابي الجليل سعد ابن أبي وقاص - كما أشرنا - مدفون في المدينة المنورة , كما أن المراجع التاريخية العربية لم تشر لأي زيارة له للصين , إلا أن المصادر التاريخية الإسلامية وغير الإسلامية الصينية بدأت في حقيقة الأمر منذ حوالي القرن الرابع عشر وحتى السابع عشر تؤكد باستمرار أن رجلاً يدعى سعد وقاص وأحياناً وانغ قاص قد زار الصين في القرن السابع الميلادي ( الأول الهجري ) ودُفن في مدينة قوانغتشو .',
#   'word_index': 15,
#   'candidates': [{'entity': 'Q380184',
#     'label': 'سعد بن أبي وقاص',
#     'description': 'سعد بن أبي وقاص صحابي وقائد مسلم وأحد العشرة المبشرين بالجنة عند المسلمين السنةالمهنة: تاجر, قائد عسكري جزء من: صحابة',
#     'ner_tag': 'PERS'}]},
#  {'word': 'محمد خاتمي ',
#   'tag': 'PERS',
#   'sentence': 'كما أن انهيار اسعار النفط سيعني أن يهبط دخل إيران إلى عشرة بلايين دولار هذه السنة من 16 بليوناً سنة 1996 ، وسيعني بالتالي أن مشاريع كثيرة وإصلاحات ستطوى مما سيفقد العهد الجديد كثيرا من شعبيته ، خصوصا إذا عرفنا أن 700 ألف شاب وشابة يدخلون سوق العمل في إيران كل سنة مع توافر وظائف لحوالي نصفهم فقط ويضيف رئيس تحرير جريدة  الوفاق : " إن المارد بدأ يخرج من القمقم وما لم نستعد له فإننا نكون أمام معضلة حقيقية " . . القوى الصاعدة الجديدة تصادف وصولنا إلى مشهد في جمهورية إيران الإسلامية خلال شهر مايو الماضي مع ذكرى مرور عام كامل على انتخاب الرئيس الدكتور محمد خاتمي رئيسا ثالثا للجمهورية الإسلامية .',
#   'word_index': 107,
#   'candidates': [{'entity': 'Q180795',
#     'label': 'محمد خاتمي',
#     'description': 'محمد خاتمي سياسي شهير إصلاحي، فقيه شيعي، مؤلف ومثقف إيرانيالمهنة: عالِم, سياسي, أمين مكتبة, كاتب, شريك منتدى دولي, عسكري',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q6400887',
#     'label': 'خاتمی',
#     'description': 'خاتمی اسم العائلة',
#     'ner_tag': None},
#    {'entity': 'Q5958272',
#     'label': 'محمد أمير خاتمي',
#     'description': 'محمد أمير خاتمي قائد القوات الجوية الإيرانية في العهد البهلوي',
#     'ner_tag': 'ORG'},
#    {'entity': 'Q16051919',
#     'label': '',
#     'description': ' لاعب كرة قدم إيرانيالمهنة: لاعب كرة قدم',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q19793724',
#     'label': '',
#     'description': ' مقالة ويكي أخبار',
#     'ner_tag': None},
#    {'entity': 'Q25432599',
#     'label': '',
#     'description': ' صفحة توضيح لويكيميديا',
#     'ner_tag': 'ORG'}]},
#  {'word': 'دبي ',
#   'tag': 'LOC',
#   'sentence': 'من اين . . . هذا ؟ > لكنك ما شاء الله تمتلكين شركة إنتاج ، وانتجت فيلماً سينمائياً كلّف حوالي 3 ملايين درهماً ، وتقيمين في ارقى شوارع دبي ، وتقودين أفخم السيارات ، من أين لك كل هذا ؟ ـ من شغلي .',
#   'word_index': 29,
#   'candidates': [{'entity': 'Q612',
#     'label': 'دبي',
#     'description': 'دبي عاصمة إمارة دبي، إحدى الإمارات السبع المكونة للإمارات العربية المتحدةتقع في: إمارة دبي البلد: الإمارات العربية المتحدة تاريخ التأسيس: ',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q613',
#     'label': 'إمارة دبي',
#     'description': 'إمارة دبي إحدى الإمارات السبع المكونة للإمارات العربية المتحدةتقع في: الإمارات العربية المتحدة البلد: الإمارات العربية المتحدة',
#     'ner_tag': 'ORG'},
#    {'entity': 'Q7715973',
#     'label': 'دبيان',
#     'description': 'دبيان نظام تشغيل للحاسوبفئة فرعية من: جنو/لينكس, لينكس تاريخ التأسيس: ',
#     'ner_tag': None},
#    {'entity': 'Q1339539',
#     'label': 'دبيلة',
#     'description': 'دبيلة في إطار تجويف ذري موجود طبيعياًفئة فرعية من: ',
#     'ner_tag': None},
#    {'entity': 'Q11788',
#     'label': 'دبيات',
#     'description': 'دبيات فَصيلة من الثديياتفئة فرعية من: لواحم',
#     'ner_tag': 'ORG'},
#    {'entity': 'Q856800',
#     'label': 'دبيق',
#     'description': 'دبيق جنس من النباتات',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q947404',
#     'label': 'دبيتسا',
#     'description': 'دبيتسا مدينة ومدينة بولنداتقع في: مقاطعة ديوبيتسا البلد: بولندا, الحكومة العامة, بولندا, الإمبراطورية النمساوية المجرية, الإمبراطورية النمساوية, ملكية هابسبورغ, الكومنولث البولندي الليتواني, مملكة بولندا تاريخ التأسيس: ',
#     'ner_tag': 'LOC'}]},
#  {'word': 'هونج كونج ',
#   'tag': 'LOC',
#   'sentence': 'وماذا عن الاقتصاد الحكومي ؟ على أننا نسمع أشياء أخرى من واحد من رجال الاقتصاد الحكوميين في هونج كونج .',
#   'word_index': 17,
#   'candidates': [{'entity': 'Q8646',
#     'label': 'هونغ كونغ',
#     'description': 'هونغ كونغ منطقة إدارية خاصة في الصينجزء من: الصين, شرق آسيا تقع في: الصين, الإمبراطورية البريطانية البلد: الصين, الإمبراطورية البريطانية تاريخ التأسيس: , ',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q751361',
#     'label': 'هونج كونج للمقاصة وتداول الأوراق المالية',
#     'description': 'هونج كونج للمقاصة وتداول الأوراق المالية شركة صينيةتقع في: هونغ كونغ البلد: الصين, هونغ كونغ تاريخ التأسيس:  موقع المقر: هونغ كونغ legal form: شركة مساهمة',
#     'ner_tag': 'ORG'},
#    {'entity': 'Q27159717',
#     'label': 'هونج كونج إي بريكس',
#     'description': 'هونج كونج إي بريكس الوصف لم يُعثرفئة فرعية من: فورمولا إي بريكس تاريخ التأسيس: ',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q26945008',
#     'label': 'هونج كونج إي بريكس 2016',
#     'description': 'هونج كونج إي بريكس 2016 :جزء من: بطولة العالم للفورمولا إي 2016–17 البلد: الصين',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q62022749',
#     'label': 'هونج كونج إي بريكس 2019',
#     'description': 'هونج كونج إي بريكس 2019 :جزء من: بطولة العالم للفورمولا إي 2018–19 البلد: الصين',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q44402041',
#     'label': 'هونج كونج إي بريكس 2017 (السباق 1)',
#     'description': 'هونج كونج إي بريكس 2017 (السباق 1) العرقجزء من: بطولة العالم للفورمولا إي 2017–18 البلد: الصين',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q79322330',
#     'label': 'هونج كونج إي بريكس 2017 (السباق 2)',
#     'description': 'هونج كونج إي بريكس 2017 (السباق 2) الوصف لم يُعثرجزء من: بطولة العالم للفورمولا إي 2017–18 البلد: الصين',
#     'ner_tag': 'LOC'}]},
#  {'word': 'قرية بوادي ',
#   'tag': 'ORG',
#   'sentence': 'وأضاف الحزب أن القوة الإسرائيلية المهاجمة حاولت السيطرة علي مدرسة قرية بوادي , ونفي المتحدث الأنباء التي ترددت عن مقتل3  من الحزب في الاشتباكات .',
#   'word_index': 10,
#   'candidates': []},
#  {'word': 'لبنان ',
#   'tag': 'LOC',
#   'sentence': 'يأتي ذلك في الوقت الذي وصلت فيه قوة من سلاح الهندسة الفرنسي تضم نحو50  عنصرا عن طريق البحر إلي ميناء بلدة  الناقورة الحدودية في جنوب لبنان .',
#   'word_index': 25,
#   'candidates': [{'entity': 'Q822',
#     'label': 'لبنان',
#     'description': 'لبنان دولة في غرب آسياجزء من: الشرق الأوسط, غرب آسيا البلد: لبنان تاريخ التأسيس: ',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q993523',
#     'label': 'لبنان',
#     'description': 'لبنان مدينة في مقاطعة غرافتون، الولايات المتحدةتقع في: مقاطعة غرافتون البلد: الولايات المتحدة تاريخ التأسيس: ',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q1016139',
#     'label': 'لبنان',
#     'description': 'لبنان مدينة في ولاية بنسيلفانيا الأمريكيةتقع في: مقاطعة لبنان البلد: الولايات المتحدة تاريخ التأسيس: ',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q1520670',
#     'label': 'لبنان',
#     'description': 'لبنان مدينة في مقاطعة ويلسون، الولايات المتحدةتقع في: مقاطعة ويلسون البلد: الولايات المتحدة تاريخ التأسيس: ',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q922352',
#     'label': 'لبنان',
#     'description': 'لبنان مدينة في مقاطعة بوون، الولايات المتحدةتقع في: مقاطعة بوون البلد: الولايات المتحدة تاريخ التأسيس: ',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q1998390',
#     'label': 'لبنان',
#     'description': 'لبنان مدينة في ولاية أوريغون، الولايات المتحدة الأمريكيةتقع في: مقاطعة لين البلد: الولايات المتحدة تاريخ التأسيس: ',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q1012355',
#     'label': 'لبنان',
#     'description': 'لبنان مدينة في مقاطعة ماريون، الولايات المتحدةتقع في: مقاطعة ماريون البلد: الولايات المتحدة',
#     'ner_tag': 'LOC'}]},
#  {'word': 'تامر حبيب ',
#   'tag': 'PERS',
#   'sentence': 'لا اريد الحديث عن القصة تفادياً لحرقها ، لكنه سيدور حول التركيبة السكانية المتنوعة الموجودة في الامارات ، وسيشارك فيه فنانون من مصر والإمارات وسوريا والمغرب ، وسيكتب القصة الكويتي طالب الدوسري ، أما السيناريو فسيكتبه السيناريست المصري الموهوب تامر حبيب .',
#   'word_index': 39,
#   'candidates': [{'entity': 'Q106947003',
#     'label': 'تامر حبيب',
#     'description': 'تامر حبيب كاتب مصريالمهنة: كاتب, ممثل',
#     'ner_tag': 'PERS'}]},
#  {'word': 'دولار ',
#   'tag': 'MISC',
#   'sentence': 'وكان هذا الاحتياطي قد بلغ حوالي 20 مليون دولار قبل إفلاس سوق العقارات ، ولكن هذا الكم لم يستطع مجابهة العواصف المتتالية التي أصابت الميزانية ، وفي عام 1984 رفع وزير المالية الضرائب على الدخل والضرائب العقارية بنسبة 2% فأصبحت ضريبة الدخل 17% والعقارية 18% ، كما عوم أسس السندات الحكومية بمبلغ بليون دولار وهو أول دين حكومي لعشر سنوات .',
#   'word_index': 53,
#   'candidates': [{'entity': 'Q14083',
#     'label': 'دولار',
#     'description': 'دولار اسم عملات متعددةفئة فرعية من: عملة',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q4917',
#     'label': 'دولار أمريكي',
#     'description': 'دولار أمريكي العملة الرسمية إلى الولايات المتحدة الأمريكيهالبلد: الولايات المتحدة',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q259502',
#     'label': 'دولار أسترالي',
#     'description': 'دولار أسترالي عملة متداولةالبلد: أستراليا',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q1104069',
#     'label': 'دولار كندي',
#     'description': 'دولار كندي عملة كنداالبلد: كندا',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q31015',
#     'label': 'دولار هونغ كونغ',
#     'description': 'دولار هونغ كونغ عملة متداولةالبلد: الصين, هونغ كونغ',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q550207',
#     'label': 'دولار أمريكي دولي',
#     'description': 'دولار أمريكي دولي وحدة افتراضية من العملةفئة فرعية من: دولار',
#     'ner_tag': None},
#    {'entity': 'Q1472704',
#     'label': 'دولار نيوزيلندي',
#     'description': 'دولار نيوزيلندي عملة متداولةالبلد: نيوزيلندا',
#     'ner_tag': 'LOC'}]},
#  {'word': 'نيو أورليانز ',
#   'tag': 'LOC',
#   'sentence': 'ويبدأ الفيلم بلقطات تحوي تناقضا مثيرا للسخرية بين استعراضات وحفلات كانت تقام في نيو أورليانز وأخرى لحطام وجثث طافية على المياه ومنازل مدمرة وفي الخلفية أغنية " هل تعرف ماذا يعني أن تفتقد نيو أورليانز " .',
#   'word_index': 33,
#   'candidates': [{'entity': 'Q34404',
#     'label': 'نيو أورلينز',
#     'description': 'نيو أورلينز مدينة في الولايات المتحدةتقع في: أولاً - البلد: الولايات المتحدة تاريخ التأسيس: ',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q172435',
#     'label': 'نيو أورليانز سينتس',
#     'description': 'نيو أورليانز سينتس فريق كرةقدم أمريكيةجزء من: )أكـل مـا البلد: الولايات المتحدة تاريخ التأسيس: ',
#     'ner_tag': 'ORG'},
#    {'entity': 'Q172339',
#     'label': 'نيو أورلينز بيليكانز',
#     'description': 'نيو أورلينز بيليكانز فريق كرة السلة المهني الأمريكيجزء من: شعبة جنوب غرب البلد: الولايات المتحدة تاريخ التأسيس:  موقع المقر: نيو أورلينز',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q7010746',
#     'label': 'نيولِن Marrittt',
#     'description': 'نيولِن Marrittt فندق في نيو أورلينز، الولايات المتحدةتقع في: نيو أورلينز البلد: الولايات المتحدة تاريخ التأسيس: ',
#     'ner_tag': 'PERS'}]},
#  {'word': 'وعبير أحمد ',
#   'tag': 'PERS',
#   'sentence': 'ولكي اكون منصفة ، لا ننكر ان الخليج فتح المجال لفنانات كثيرات مصريات ، مثل لمياء طارق وعبير أحمد وعبير الجندي ، وهؤلاء تعبن واصبح لهن مكانتهن على الساحة الفنية ، ولا ننسى يلدا الايرانية التي اخذت مكانا متميزا في الدراما الخليجية ، وفي المقابل مصر معروفة باحتضان الفنانين العرب .',
#   'word_index': 17,
#   'candidates': [{'entity': 'Q12224291',
#     'label': 'عبير أحمد',
#     'description': 'عبير أحمد ممثلة مصريةالمهنة: ممثل',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q123216367',
#     'label': 'عبير أحمد عوض غراب',
#     'description': 'عبير أحمد عوض غراب فلسطيني ضحية القصف الإسرائيلي على قطاع غزة أكتوبر 2023.',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q123210543',
#     'label': 'عبير أحمد عبد الرحمن علي',
#     'description': 'عبير أحمد عبد الرحمن علي فلسطيني ضحية القصف الإسرائيلي على قطاع غزة أكتوبر 2023.',
#     'ner_tag': 'PERS'}]},
#  {'word': 'الحنين إلى النبي ',
#   'tag': 'LOC',
#   'sentence': 'ولكن الكتابات المنقوشة على لوحة تجديد بناء المسجد والمنقوشة بيد قوه جيان سنة 1350م تشير إلى أن المسجد قد بُني إبان أسرة تانغ , وأن تسمية هوايشنغ تعني الحنين إلى النبي , وقد تعرض المسجد خاصة المصلى الرئيسي إلى الخراب مرات عدة إحداها ما أشارت إليه لوحة تجديد بناء المسجد إذ تقول ( تم تدمير المسجد في سنة 1343م من عهد الامبراطور تشيتشنغ من أسرة يوان : التقت ( العربي ) إمام مسجد الحنين إلى النبي الإمام اسماعيل وانغ قوانغ شوى في مكتبه داخل المسجد , حيث رحّب بنا بحرارة مشيداً باهتمام العرب بتفقد آثارهم وأحوال إخوانهم في العقيدة , مؤكداً أن هذا المسجد ليس قطعة أثرية فحسب , بل هو مركز ثقافي كبير لتعزيز التواصل بين العرب والصينيين , ودليل على التواصل الحضاري بين الحضارتين العربية والصينية , مشيراً إلى أن عدد المسلمين الصينيين المسجلين الآن في المدينة سبعة آلاف مسلم يعتزون بعقيدتهم الإسلامية مشيراً إلى أن الجمعية الإسلامية الصينية بالمدينة تحرص على حماية المساجد والآثار العربية , كما ترسل شباب المسلمين إلى الدول العربية لدراسة اللغة العربية والعلوم الإسلامية , وأضاف الإمام إسماعيل إن المدينة تضم عددا من المساجد أهمها بعد مسجد الحنين إلى النبي مسجد هوبان .',
#   'word_index': 28,
#   'candidates': []},
#  {'word': 'الله ',
#   'tag': 'MISC',
#   'sentence': 'وينقسم المسجد إلى ثلاثة أقسام رئيسية وهي المصلى المستطيل الشكل والمسقوف بالقرميد الأحمر على طريقة العمارة الصينية , أما السقف فيستند على عمودين مزخرفين بآيات كريمة مخطوطة بالخط العربي الصيني وخطت في صدر المصلى ( إن الدين عند الله الإسلام ) , كما يوجد منبر خشبي أصبح جزءاً أصيلاً من ملامح المساجد في الصين .',
#   'word_index': 38,
#   'candidates': [{'entity': 'Q190',
#     'label': 'الله',
#     'description': 'الله عَلَم على الإله الخالق المَعْبُود بحقفئة فرعية من: الخالق, شخص, شخصية دينية',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q825',
#     'label': 'الله',
#     'description': 'الله الإيمان والمفهوم المسيحي باللهفئة فرعية من: الله لديه جزء: الله الآب, الروح القدس, الله الابن',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q234801',
#     'label': 'الله',
#     'description': 'الله كلمة عربية',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q3648715',
#     'label': 'الله',
#     'description': 'الله الإنكليزية لغة الإنكليزية',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q87543941', 'label': 'ﷲ', 'description': 'ﷲ ', 'ner_tag': None},
#    {'entity': 'Q37302',
#     'label': 'الروح القدس',
#     'description': 'الروح القدس في مختلف الاديانجزء من: divine providence',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q31077288',
#     'label': 'الله',
#     'description': 'الله الوصف لم يُعثر',
#     'ner_tag': None}]},
#  {'word': 'يوان ',
#   'tag': 'PERS',
#   'sentence': 'ولكن الكتابات المنقوشة على لوحة تجديد بناء المسجد والمنقوشة بيد قوه جيان سنة 1350م تشير إلى أن المسجد قد بُني إبان أسرة تانغ , وأن تسمية هوايشنغ تعني الحنين إلى النبي , وقد تعرض المسجد خاصة المصلى الرئيسي إلى الخراب مرات عدة إحداها ما أشارت إليه لوحة تجديد بناء المسجد إذ تقول ( تم تدمير المسجد في سنة 1343م من عهد الامبراطور تشيتشنغ من أسرة يوان : التقت ( العربي ) إمام مسجد الحنين إلى النبي الإمام اسماعيل وانغ قوانغ شوى في مكتبه داخل المسجد , حيث رحّب بنا بحرارة مشيداً باهتمام العرب بتفقد آثارهم وأحوال إخوانهم في العقيدة , مؤكداً أن هذا المسجد ليس قطعة أثرية فحسب , بل هو مركز ثقافي كبير لتعزيز التواصل بين العرب والصينيين , ودليل على التواصل الحضاري بين الحضارتين العربية والصينية , مشيراً إلى أن عدد المسلمين الصينيين المسجلين الآن في المدينة سبعة آلاف مسلم يعتزون بعقيدتهم الإسلامية مشيراً إلى أن الجمعية الإسلامية الصينية بالمدينة تحرص على حماية المساجد والآثار العربية , كما ترسل شباب المسلمين إلى الدول العربية لدراسة اللغة العربية والعلوم الإسلامية , وأضاف الإمام إسماعيل إن المدينة تضم عددا من المساجد أهمها بعد مسجد الحنين إلى النبي مسجد هوبان .',
#   'word_index': 65,
#   'candidates': [{'entity': 'Q716212',
#     'label': 'يوان',
#     'description': 'يوان )اللغة(',
#     'ner_tag': 'ORG'},
#    {'entity': 'Q2264383',
#     'label': 'يوان',
#     'description': 'يوان اسم العائلة',
#     'ner_tag': 'ORG'},
#    {'entity': 'Q3572350',
#     'label': 'يوان',
#     'description': 'يوان أسم مذكر معطى (Yoann)',
#     'ner_tag': 'ORG'},
#    {'entity': 'Q1378945',
#     'label': 'يوان صيني',
#     'description': 'يوان صيني عملة الصينفئة فرعية من: y y y y y',
#     'ner_tag': 'ORG'},
#    {'entity': 'Q434401',
#     'label': 'يوان',
#     'description': 'يوان فنان قصص مصورة فرنسيالمهنة: فنان قصص مصورة',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q147220',
#     'label': 'يوان مي',
#     'description': 'يوان مي شاعر صينيالمهنة: رسام, شاعر, كاتب, خطاط, كاتب غنائي, سياسي',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q183199',
#     'label': 'يوانينا',
#     'description': 'يوانينا مستوطنة في اليونانتقع في: بلدية إيوانينا البلد: اليونان',
#     'ner_tag': 'LOC'}]},
#  {'word': 'الخليج ',
#   'tag': 'LOC',
#   'sentence': 'ولا أنكر أن هناك فئة تأتي الى الخليج وتمارس سلوكاً منحرفاً ، مما ساعد في ترسيخ إنطباع غير جيد عن المغربيات .',
#   'word_index': 7,
#   'candidates': [{'entity': 'Q39594',
#     'label': 'خليج صغير',
#     'description': 'خليج صغير مسطح مائي متصل بمحيط أو بحيرة، تشكله المسافة البعيدة عن الشاطئفئة فرعية من: خط الساحل, مساحة ماء',
#     'ner_tag': None},
#    {'entity': 'Q874980',
#     'label': 'الخليج',
#     'description': 'الخليج مقاطعة في بابوا غينيا الجديدةتقع في: بابوا غينيا الجديدة البلد: بابوا غينيا الجديدة',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q1211833',
#     'label': 'الخليج',
#     'description': 'الخليج فيلم أنتج عام 2009',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q34675',
#     'label': 'الخليج العربي',
#     'description': 'الخليج العربي خليج يمتد من خليج عُمان جنوبا حتى شط العرب شمالاجزء من: المحيط الهندي, بحر اریترا البلد: السعودية, إيران, سلطنة عمان, الإمارات العربية المتحدة, قطر, البحرين, الكويت, العراق',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q186733',
#     'label': 'الخليج الأسترالي العظيم',
#     'description': 'الخليج الأسترالي العظيم خليج المحيط قبالة الأجزاء الوسطى والغربية من الساحل الجنوبي للبر الرئيسي لأسترالياجزء من: المحيط الهندي تقع في: أستراليا البلد: أستراليا',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q211779',
#     'label': 'الخليج الساروني',
#     'description': 'الخليج الساروني خليج في اليونانلديه جزء: منبر من طراز جزء من: بحر إيجة تقع في: بيلوبونيز, أتيكا, بيرايوس, جزر, أرغوليذا, كورينثيا البلد: اليونان',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q210305',
#     'label': 'خليج فنزويلا',
#     'description': 'خليج فنزويلا خليج في غرب فنزويلاجزء من: البحر الكاريبي البلد: فنزويلا, كولومبيا',
#     'ner_tag': 'MISC'}]},
#  {'word': 'هونج كونج ',
#   'tag': 'LOC',
#   'sentence': 'وبالتأكيد فإن الأرض هي واحدة من أكبر المشاكل في هونج كونج .',
#   'word_index': 9,
#   'candidates': [{'entity': 'Q8646',
#     'label': 'هونغ كونغ',
#     'description': 'هونغ كونغ منطقة إدارية خاصة في الصينجزء من: الصين, شرق آسيا تقع في: الصين, الإمبراطورية البريطانية البلد: الصين, الإمبراطورية البريطانية تاريخ التأسيس: , ',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q751361',
#     'label': 'هونج كونج للمقاصة وتداول الأوراق المالية',
#     'description': 'هونج كونج للمقاصة وتداول الأوراق المالية شركة صينيةتقع في: هونغ كونغ البلد: الصين, هونغ كونغ تاريخ التأسيس:  موقع المقر: هونغ كونغ legal form: شركة مساهمة',
#     'ner_tag': 'ORG'},
#    {'entity': 'Q27159717',
#     'label': 'هونج كونج إي بريكس',
#     'description': 'هونج كونج إي بريكس الوصف لم يُعثرفئة فرعية من: فورمولا إي بريكس تاريخ التأسيس: ',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q26945008',
#     'label': 'هونج كونج إي بريكس 2016',
#     'description': 'هونج كونج إي بريكس 2016 :جزء من: بطولة العالم للفورمولا إي 2016–17 البلد: الصين',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q62022749',
#     'label': 'هونج كونج إي بريكس 2019',
#     'description': 'هونج كونج إي بريكس 2019 :جزء من: بطولة العالم للفورمولا إي 2018–19 البلد: الصين',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q44402041',
#     'label': 'هونج كونج إي بريكس 2017 (السباق 1)',
#     'description': 'هونج كونج إي بريكس 2017 (السباق 1) العرقجزء من: بطولة العالم للفورمولا إي 2017–18 البلد: الصين',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q79322330',
#     'label': 'هونج كونج إي بريكس 2017 (السباق 2)',
#     'description': 'هونج كونج إي بريكس 2017 (السباق 2) الوصف لم يُعثرجزء من: بطولة العالم للفورمولا إي 2017–18 البلد: الصين',
#     'ner_tag': 'LOC'}]},
#  {'word': 'إيران ',
#   'tag': 'LOC',
#   'sentence': 'الأستاذ محمد السعدي يصف معرض  طهران للكتاب بأنه منذ تأسيسه شكل ظاهرة ثقافية كبرى في إيران والمنطقة وقد سجل أرقاما قياسية من المشاركة والمعروض من الكتب ، وخاصة في القسم العربي ، إذا اخذنا بعين الاعتبار أن إيران بلد غير عربي ، ويشارك في المعرض عدد كبير من الناشرين العرب .',
#   'word_index': 37,
#   'candidates': [{'entity': 'Q794',
#     'label': 'إيران',
#     'description': 'إيران دولة في الشرق الأوسطجزء من: الشرق الأوسط, غرب آسيا البلد: إيران تاريخ التأسيس: , , , , , , ',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q9168',
#     'label': 'الفارسية',
#     'description': 'الفارسية لغة هندوأوروبية يُتحدث بها رئيسيًّا في إيران وأفغانستان وطاجيكستانفئة فرعية من: جديد فارسي جزء من: لغات إيران البلد: إيران, البحرين, الكويت, أفغانستان, باكستان, طاجيكستان, أوزبكستان, روسيا, الإمارات العربية المتحدة',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q25763',
#     'label': 'إيران الكبرى',
#     'description': 'إيران الكبرى منطقة تاريخية في إيرانجزء من: تاريخ إيران البلد: إيران, العراق, سوريا, تركيا, أرمينيا, جورجيا, أذربيجان, روسيا, تركمانستان, أوزبكستان, طاجيكستان, قيرغيزستان, كازاخستان, الصين, باكستان, أفغانستان',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q131350',
#     'label': 'نيسابور',
#     'description': 'نيسابور المدينة القديمة المشهورة وهي في شمال شرق إيرانتقع في: المنطقة الوسطى البلد: إيران',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q1672477',
#     'label': 'شعوب إيرانية',
#     'description': 'شعوب إيرانية الشعب الإيرانيفئة فرعية من: الأقوام الهندوأوروبية جزء من: الأقوام الهندوأوروبية',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q10859757',
#     'label': 'ايران',
#     'description': 'ايران صحيفة إيرانيةالبلد: إيران تاريخ التأسيس: ',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q913272',
#     'label': 'إيراندايو',
#     'description': 'إيراندايو بلدية في إسبانياتقع في: الكبير الكبير البلد: إسبانيا',
#     'ner_tag': 'LOC'}]},
#  {'word': 'برضا ',
#   'tag': 'PERS',
#   'sentence': '> ماذا حدث بعد ذلك ؟ ـ عرضت الفيلم على المطرب العراقي رضا العبد الله ، لكنني عندما علمت بمنع رضا من الكويت ، شعرت بأنني كمنتجة سأخاطر بسوق كبير مثل سوق الكويت ، اذا تم منع عرض الفيلم في السينما الكويتية ، فقمت بالاعتذار لـ رضا عن طريق وسيط ، لأني مرغمة على ذلك ، إلا أنني فوجئت برضا يشن هجوماً على الفيلم قبل عرضه ، واخذ يصف القصة بالتافهة ، رغم أنه كان من أشد المعجبين بالقصة والمتحمسين لها ، وطلب ان يضع الموسيقى التصويرية والالحان .',
#   'word_index': 59,
#   'candidates': [{'entity': 'Q19470290',
#     'label': 'بِرِضابه ماء الحَياة',
#     'description': 'بِرِضابه ماء الحَياة قصيدة من تأليف عائشة التيمورية',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q19459699',
#     'label': 'برضاك أدفع للسخط',
#     'description': 'برضاك أدفع للسخط قصيدة من تأليف عبد الغني النابلسي',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q19459694',
#     'label': 'برضابِ ثغرك يستغيْ',
#     'description': 'برضابِ ثغرك يستغيْ قصيدة من تأليف ابن الرومي',
#     'ner_tag': None},
#    {'entity': 'Q651630',
#     'label': 'لم تكن كيكيKKKskkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKK',
#     'description': 'لم تكن كيكيKKKskkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKK قرية في منطقة أوستي ند لابيمتقع في: مقاطعة ليتوميريتسه,  البلد: التشيك',
#     'ner_tag': None}]},
#  {'word': 'بعلبك ',
#   'tag': 'LOC',
#   'sentence': '. ولبنان يهدد بوقف نشر الجيش في الجنوب بيروت ـ من فتحي محمود ـ القدس ـ وكالات الأنباء طليعة القوة الفرنسية لدى وصولها الى الناقورة في خرق فاضح لقرار مجلس الأمن رقم ( 1701 ) الخاص بوقف العمليات العسكرية في لبنان , قام الجيش الإسرائيلي بعملية إنزال جوية , في وقت مبكر من صباح أمس , بالقرب من مدينة بعلبك اللبنانية , وقد تمكن مقاتلو حزب الله من إرغام الوحدة الإسرائيلية , التي تم إنزالها , علي التراجع , بعد اشتباك عنيف بين الطرفين , أسفر عن مصرع ضابط إسرائيلي , وإصابة ضابطين آخرين , أحدهما إصابته بالغة .',
#   'word_index': 59,
#   'candidates': [{'entity': 'Q178835',
#     'label': 'بعلبك',
#     'description': 'بعلبك مدينة لبنانيةتقع في: محافظة بعلبك الهرمل, قضاء بعلبك البلد: لبنان تاريخ التأسيس: ',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q37095247',
#     'label': 'البعلبكي',
#     'description': 'البعلبكي اسم عائلة',
#     'ner_tag': None},
#    {'entity': 'Q117168154',
#     'label': 'عماد بعلبكي',
#     'description': 'عماد بعلبكي أستاذ جامعي وأكاديمي لبنانيالمهنة: أستاذ جامعي, أستاذ جامعي',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q117168204',
#     'label': 'رلى بعلبكي',
#     'description': 'رلى بعلبكي أستاذة جامعية ومُترجمة لُبنانيةالمهنة: أستاذ جامعي, مترجم',
#     'ner_tag': None},
#    {'entity': 'Q782804',
#     'label': 'قضاء بعلبك',
#     'description': 'قضاء بعلبك منطقة إدارية في محافظة بعلبك الهرملتقع في: محافظة بعلبك الهرمل البلد: لبنان',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q12198763',
#     'label': 'بعلبكي',
#     'description': 'بعلبكي صفحة توضيح لويكيميديا',
#     'ner_tag': None}]},
#  {'word': 'قوانغتشو ',
#   'tag': 'LOC',
#   'sentence': 'ويشير النصب ( إلى أنه من المذهل أن القتلة قد انتحروا جميعاً بعد ارتكابهم لهذه المذبحة , ويشير الذين جددوا هذه اللوحة إلى أنهم التزموا بشكل كامل بالكتابات الموجودة في اللوحة الأصلية , وتم تجديد اللوحة في السنة السابعة من حكم الإمبراطور جاتشينغ ( 1796 - 1820م ) واللوحة الحجرية تتحدث عن مجازر تعرض لها المسلمون , وربما تكون المعلومات التي نقلتها اللوحة التاريخية هي صدى لتمرّد خوان تشاو في عام 875م الذي راح ضحيته الكثير من العرب المسلمين في مدينة قوانغتشو وغيرها من المدن الصينية .',
#   'word_index': 81,
#   'candidates': [{'entity': 'Q16572',
#     'label': 'غوانزو',
#     'description': 'غوانزو مدينة صينيةجزء من: دلتا نهر اللؤلؤة تقع في: غوانغدونغ,  البلد: الصين',
#     'ner_tag': 'ORG'}]},
#  {'word': 'والحيرة ',
#   'tag': 'LOC',
#   'sentence': 'ونستدل من المصادر الصينية ككتاب تاريخ أسرة هان ( 206 ق . م - 220 م ) وكتاب السجلات التاريخية ( 91 ق . م ) وكذلك المصادر العربية - لمروج الذهب لأبي الحسن المسعودي , أن هنالك اتصالات بين الصين والعرب قبل الإسلام , وإن مدنا كمدن عمان والحيرة قد ذكرت في المصادر الصينية القديمة , كما رصد وفد من بلاد العراق في البلاط الصيني في حوالي عام 120م , وقد قدم الوفد طائر ببغاء هدية للإمبراطور , وكانت المرة الأولى التي يرى فيها الصينيون هذا الطائر ولا يزالون يطلقون عليه اسم ( باباغا ) .',
#   'word_index': 49,
#   'candidates': [{'entity': 'Q310799',
#     'label': 'الحيرة',
#     'description': 'الحيرة مدينة بائدةتقع في: محافظة النجف البلد: العراق',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q12225367',
#     'label': 'عزلة الحيرة',
#     'description': 'عزلة الحيرة عزلة في مديرية حرف سفيان التابعة لمحافظة عمران اليمنيةتقع في: مديرية حرف سفيان, محافظة عمران البلد: اليمن',
#     'ner_tag': 'ORG'},
#    {'entity': 'Q20390255',
#     'label': 'الحيرة',
#     'description': 'الحيرة محلة في قرية خدش، عزلة حمير، مديرية القفر، محافظة إب اليمنيةتقع في: خدش البلد: اليمن',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q12186877',
#     'label': 'الحيرة',
#     'description': 'الحيرة فيلم مغربي',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q4704012',
#     'label': 'الحيرة (الشارقة)',
#     'description': 'الحيرة (الشارقة) مستوطنة في الإمارات العربية المتحدةتقع في: إمارة الشارقة البلد: الإمارات العربية المتحدة',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q12186878',
#     'label': 'الحيره، عمران',
#     'description': 'الحيره، عمران مستوطنة في اليمنالبلد: اليمن',
#     'ner_tag': 'ORG'},
#    {'entity': 'Q28970453',
#     'label': 'الحيرة',
#     'description': 'الحيرة صفحة توضيح لويكيميديا',
#     'ner_tag': 'ORG'}]},
#  {'word': 'طهماسب ',
#   'tag': 'PERS',
#   'sentence': 'في تلك العصور لم تكن مدينة مشهد وأهاليها بمأمن من غارات " الأزبك " إلى أن انتقل الحكم إلى العائلة الصفوية في القرن السادس عشر للميلاد ، فأصبح المذهب الشيعي هو المذهب الرسمي للدولة ، ففي عهد " الشاه إسماعيل الأول " و  " الشاه طهماسب " و  " الشاه عباس الأول " أصبحت مدينة مشهد والحرم الرضوي الشريف ذات أهمية بالغة لدى المسلمين ، وكان السلاطين يزورون المقام بين الفينة وا لفينة يقدمون الهدايا والنذور للمقام وأحيانا كانوا يصدرون الأوامر ببناء أماكن حول الحرم الشريف حيث إن مدينة  مشهد في القرن الثامن عشر الميلادي استطاعت أن تثبت وجودها كأكبر مدينة مذهبية وإسلامية يقصدها المسلمون من جميع أنحاء العالم للزيارة والتبرك بمقام الإمام الرضا .',
#   'word_index': 45,
#   'candidates': [{'entity': 'Q298410',
#     'label': 'طهماسب الأول',
#     'description': 'طهماسب الأول شاه إيرانالمهنة: حاكم',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q374516',
#     'label': 'طهماسب الثاني',
#     'description': 'طهماسب الثاني من عام 1729 إلى عام 1732المهنة: حاكم',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q5809593',
#     'label': 'طهماسب أباد',
#     'description': 'طهماسب أباد قرية في إيرانتقع في: قسم سلطانیة الریفي البلد: إيران',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q7675590',
#     'label': 'طهماسب أباد',
#     'description': 'طهماسب أباد منطقة سكنية في إيرانتقع في: قسم أرشق الشرقي الريفي البلد: إيران',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q5793927',
#     'label': 'طهماسب قلي',
#     'description': 'طهماسب قلي قرية في إيرانتقع في: قسم حومة دهغلان الريفي البلد: إيران',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q5866000',
#     'label': 'طهماسب عليا',
#     'description': 'طهماسب عليا قرية في إيرانتقع في: قسم آسمان\u200cآباد الريفي البلد: إيران',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q5999356',
#     'label': 'طهماسب',
#     'description': 'طهماسب صفحة توضيح لويكيميديا',
#     'ner_tag': 'PERS'}]},
#  {'word': 'كولون ',
#   'tag': 'LOC',
#   'sentence': '. مشهد هذه المجمعات مثير ، فالواجهات تكاد تختفي وراء الملابس المغسولة المنشورة بكثرة في شرفات ونوافذ كل شقة وكأنها اعلام ملونة ، وكثرتها تؤكد أن الشقة الواحدة يتجاوز عدد سكانها العشرات بين كبار وصغار وأجداد وأحفاد ، فالتزاحم شديد لا يتوقف ، وتوافد الفارين والقادمين من الهاربين من مناطق جنوب شرق اسيا بمن في ذلك الفيتناميون والكمبوديون لا ينقطع ، حتى لقد تسبب كل ذلك في تفاقم مشكلة الإسكان برغم هذا العدد المتزايد كل عام من عقارات الإسكان العام الضخمة وخاصة في منطقة  كولون الصناعية  .',
#   'word_index': 84,
#   'candidates': [{'entity': 'Q239143',
#     'label': 'كولون، هونغ كونغ',
#     'description': 'كولون، هونغ كونغ مستوطنة في الصينتقع في: هونغ كونغ, هونغ كونغ البريطانية البلد: الصين, المملكة المتحدة',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q177449',
#     'label': 'نقطتان رأسيتان',
#     'description': 'نقطتان رأسيتان علامة ترقيم تتكون من نقطتين متساويتين تقعان على خط عمودى واحدجزء من: القول المكسل',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q276389',
#     'label': 'حزاك',
#     'description': 'حزاك تَحْلُ جواربِ المَلْك في واحد مَنْ بملابس داخليةفئة فرعية من: (أُسس), لانجري',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q2300879',
#     'label': 'كولون',
#     'description': 'كولون مستوطنة أمريكية في ولاية نبراسكاتقع في: مقاطعة ساوندرس البلد: الولايات المتحدة',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q2641272',
#     'label': 'كولون',
#     'description': 'كولون مستوطنة أمريكية في ولاية ميشيغانتقع في: مقاطعة سانت جوزيف البلد: الولايات المتحدة',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q2481248',
#     'label': 'كولون',
#     'description': 'كولون محطة مترو في مدريد، إسبانياتقع في: مدريد البلد: إسبانيا',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q365',
#     'label': 'كولونيا',
#     'description': 'كولونيا مدينة في ولاية شمال الراين وستفاليا، ألمانياتقع في: مقاطعة كولونيا, انتخابية كولونيا البلد: ألمانيا, ألمانيا النازية, جمهورية فايمار, الإمبراطورية الألمانية, مملكة بروسيا, الإمبراطورية الفرنسية الأولى, الإمبراطورية الرومانية المقدسة, انتخابية كولونيا, مملكة الفرنجة الشرقيين, إمبراطورية الفرنجة, ألمانيا المحتلة من قبل قوات التحالف, ألمانيا الغربية, الإمبراطورية الرومانية الغربية, الإمبراطورية الرومانية, ألمانيا',
#     'ner_tag': 'LOC'}]},
#  {'word': 'نانسي كوال ',
#   'tag': 'PERS',
#   'sentence': 'وقد عبرت عن ذلك " نانسي كوال " حين قالت : " أنا استمتع بكوني فتاة ، فلم يعد من العار بالنسبة للمرأة أن تشترك في مسابقات الجمال ، وأن تعمل كعارضة أزياء ، أو أن تشاهد بمفردها مع أحد الفتيات ، وهناك حرية للفتاة لم يكن يسمح بها في الأجيال السابقة " .',
#   'word_index': 5,
#   'candidates': []},
#  {'word': 'مشهد ',
#   'tag': 'LOC',
#   'sentence': 'الشاعر الفردوسي في طريق يمتد لمسافة 50 كيلومتراً من شمال غرب مدينة مشهد اتجهنا لزيارة قبر الشاعر الإيراني الشيخ أبي القاسم الفردوسي الذي ألف كتابه الشهير " الشاهنامة " وهي قصائد في الشعر الحماسي ، وقضي فيها 30 عاماً " " توفي عام 1201 " حيث يوجد في مبناه متحف جميل يحتوي على بعض التحف النادرة للمخطوطات " الشاهنامة " وقد بني عام 1982 ، لكن المدفن بدئ العمل في بنائه عام 1926 وانتهي منه عام 1934 ، لكن المدفن الرئيسي تهدم عام 1964 ، وتمت إعادة بنائه عام 1968 ويبلغ ارتفاع النصب 945 متراً وبني على مساحة 2766 مترا مربعا وتبلغ الحديقة المقام عليها حوالي 60 ألف متر مربع .',
#   'word_index': 12,
#   'candidates': [{'entity': 'Q121157',
#     'label': 'مشهد',
#     'description': 'مشهد مدينة مُقدَّسة في الإسلام وثاني أكبر مدينة في إيرانتقع في: المنطقة الوسطى البلد: إيران تاريخ التأسيس: ',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q5941905',
#     'label': 'مشهد',
#     'description': 'مشهد محطة السكك الحديدية في مشهد، إيرانتقع في: مشهد البلد: إيران',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q6783109',
#     'label': 'مشهد',
#     'description': 'مشهد مستوطنة في أفغانستانتقع في: مقاطعة_كشم البلد: أفغانستان',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q7430735',
#     'label': 'مشهد',
#     'description': 'مشهد في ميدانفئة فرعية من: المعلوماتية عن جزء من: مصطلحات علم النفس',
#     'ner_tag': None},
#    {'entity': 'Q55760865',
#     'label': 'مشهد قصير',
#     'description': 'مشهد قصير قصير قصير المشهدفئة فرعية من: لا شيء, عمل جزء من: ألف - العرض, إظهار العرض',
#     'ner_tag': None},
#    {'entity': 'Q1129474',
#     'label': 'مشهد ثقافي',
#     'description': 'مشهد ثقافي مناظر طبيعية، والتي تُنْجَسُ بشكل دائم من قِبل البشرفئة فرعية من: منظر طبيعي, كيان إقليمي جغرافي إنساني, البيئة',
#     'ner_tag': None},
#    {'entity': 'Q1286517',
#     'label': 'مشهد طبيعي',
#     'description': 'مشهد طبيعي المنظر الطبيعي الأصليفئة فرعية من: كيان إقليمي, منظر طبيعي, الإقليم الطبيعي جزء من: طبيعة',
#     'ner_tag': None}]},
#  {'word': 'خراسان ',
#   'tag': 'LOC',
#   'sentence': 'يقول المدير المسؤول السيد جلال فياضي إن التغيرات السياسية والاقتصادية التي تحدث في إيران هي نتاج طبيعي لما حدث مع بداية الثورة الإسلامية في إيران والتي رفعت شعار الحرية داخل الدولة وقد برزت إرهاصات هذه التغيرات بوضوح في الانتخابات الأخيرة لرئيس الجمهورية وهي بالتالي تعكس التطور في حقل الاقتصاد أو في الجانب الثقافي ، إن نظرة واحدة لعدد الطلاب الجامعيين في محافظة  خراسان يعطيك مؤشراً ايجابياً ، فقد ارتفع بل تضاعف عدد الطلاب بشكل كبير عن السابق .',
#   'word_index': 62,
#   'candidates': [{'entity': 'Q5845245',
#     'label': 'خراسان',
#     'description': 'خراسان قرية في إيرانتقع في: قسم نجف أباد الريفي البلد: إيران',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q587090',
#     'label': 'خراسان رضوي',
#     'description': 'خراسان رضوي إحدى محافظات إيرانتقع في: إيران البلد: إيران',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q171551',
#     'label': 'خراسان جنوبي',
#     'description': 'خراسان جنوبي إحدى محافظات إيرانتقع في: إيران البلد: إيران',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q180075',
#     'label': 'خراسان الشمالية',
#     'description': 'خراسان الشمالية إحدى محافظات إيرانتقع في: إيران البلد: إيران',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q2352322',
#     'label': 'خراسان الكبرى',
#     'description': 'خراسان الكبرى المعروفة في التراث الإسلامي بخراسانجزء من: بارس البلد: الدولة العباسية',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q2474149',
#     'label': 'خراسان',
#     'description': 'خراسان صفحة توضيح ويكيميديا',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q5842108',
#     'label': 'خراسانة',
#     'description': 'خراسانة قرية في إيرانتقع في: قسم أختاتشي الريفي البلد: إيران',
#     'ner_tag': 'LOC'}]},
#  {'word': 'دين ',
#   'tag': 'PERS',
#   'sentence': 'أنه بعد أن قام تمرّد أسبا في حوالي عام 1357 - 1366م , واضطربت الأحوال في بداية أسرة مينغ , تراجع المسلمون آنذاك إلى القرى والمناطق المحيطة بمدينة تشوانتشو وكان من بينهم أسلاف دينغ ( دين ) من الجيل الثالث المنحدرين من أسرة سيد الدين شمس الدين العربي والذين استقروا في منطقة تشن داي في الضفة الجنوبية لخليج تشوانتشو .',
#   'word_index': 35,
#   'candidates': [{'entity': 'Q9174',
#     'label': 'دين',
#     'description': 'دين نظام عقائدي مقدسفئة فرعية من: نظام الاعتقاد, أيديولوجيا, رؤية كونية, منظور ديني, تقاليد لديه جزء: قائمة القديسين جزء من: السحر والدين',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q1796595',
#     'label': 'دين',
#     'description': 'دين اسم معطى',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q383113',
#     'label': 'دين',
#     'description': 'دين اسم العائلة (Dean)',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q3196867',
#     'label': 'قرض',
#     'description': 'قرض أو سلسلة المدفوعات التي تكون مستحقة فيفئة فرعية من: إلزام جزء من: اقتصاد',
#     'ner_tag': 'ORG'},
#    {'entity': 'Q12750644',
#     'label': 'دين',
#     'description': 'دين أسم مذكر معطى',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q26779034',
#     'label': 'دين',
#     'description': 'دين اسم العائلة (Deane)',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q965805',
#     'label': 'دين',
#     'description': 'دين مغني بوسنيالمهنة: مغني',
#     'ner_tag': 'PERS'}]},
#  {'word': 'لمعرض الكتاب ',
#   'tag': 'MISC',
#   'sentence': 'جو الحرية الذي خلقته الحكومة لمعرض الكتاب انعكس على نوعية الحضور ومساهماتهم ، فالشعب الإيراني 60% منه اعمارهم تقل عن 15 سنة ، فأنت تلاحظ الشابات في اجنحة المعرض وقد بدأن في وضع مساحيق الزينة وطلاء الوجه ، كما سمحت السلطات بوضع الموسيقى ، إنها فرصة للشعب الإيراني للتعبير عما يجول في نفسه .',
#   'word_index': 5,
#   'candidates': [{'entity': 'Q998672',
#     'label': 'معرض الكتاب',
#     'description': 'معرض الكتاب مبادلات تجارية للكتبفئة فرعية من: معرض تجاري',
#     'ner_tag': None},
#    {'entity': 'Q1069103',
#     'label': 'معرض القاهرة الدولي للكتاب',
#     'description': 'معرض القاهرة الدولي للكتاب أكبر معرض للكتاب بالشرق الأوسط، وثاني أكبر معرض للكتاب في العالمتقع في: القاهرة البلد: مصر تاريخ التأسيس: ',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q25707484',
#     'label': 'معرض الكتاب في الكويت والدور النسوي في تنمية البلد',
#     'description': 'معرض الكتاب في الكويت والدور النسوي في تنمية البلد مقالة ويكي أخبار',
#     'ner_tag': 'LOC'}]},
#  {'word': 'الصين ',
#   'tag': 'LOC',
#   'sentence': 'يشرف على أحوال المسلمين في هونج كونج مجلس الأمناء ، وهو بشعبه المشتركة يختار الأمين العام الفخري وأمين الخزينة الفخري ، ويتولى المجلس شئون المساجد ومقابر المسلمين والرقابة وضبط التبرعات الممنوحة والمشتركة ، والعمل على تولي الترتيبات اللازمة للجنائز ودفن الموتى من المسلمين ، وتنظيم الصلوات في المناسبات الخاصة كالأعياد ، والتعهد بأي أعمال لصالح المسلمين العام في هونج كونج والدعاية للإسلام ، وقد زرنا ضريح سعد بن أبي وقاص فاتح الصين وهو موجود في مدينة كانتون أمام هونج كونج ، وقد أقيم حول الضريح مسجد يعتبر من أقدم المساجد التي أقيمت حتى الآن .',
#   'word_index': 71,
#   'candidates': [{'entity': 'Q148',
#     'label': 'الصين',
#     'description': 'الصين دولة في شرق آسياجزء من: الصين التاريخية, شرق آسيا البلد: الصين تاريخ التأسيس: ',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q29520',
#     'label': 'الصين التاريخية',
#     'description': 'الصين التاريخية في المنطقة الثقافية، والحضارة القديمة، والأمة في شرق آسيا، تشير في معظمها إلى جمهورية الصين الشعبية في الحالة السياسية ونادراً ما تشير إلى جمهورية الصينلديه جزء: الصين, تايوان',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q1135255',
#     'label': 'جمهورية الصين السوفيتية',
#     'description': 'جمهورية الصين السوفيتية دولة سابقةتاريخ التأسيس: ',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q20420088',
#     'label': 'الصين',
#     'description': 'الصين محلة في قرية العارضة، عزلة بني شبيب، مديرية حبيش، محافظة إب اليمنيةتقع في: العارضة البلد: اليمن',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q7850',
#     'label': 'الصينية',
#     'description': 'الصينية مجموعة اللغات التي تنتمي إلى الأسرة الصينية التبتيةفئة فرعية من: لغات صينية تبتية, م لديه جزء: لغات مين الصينية, صينية يوي, لغة الهاكا, وو, الصينية المندرينية, شيانغ صيني, جين صيني, Huechs الصينية, البنغية, با - سو صيني, شاسوتشو البلد: الصين, تايوان',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q178528',
#     'label': 'حروف صينية تقليدية',
#     'description': 'حروف صينية تقليدية رموز صينية لا تزال تستخدم لأغراض رسمية في تايوان وفي هونغ كونغ وماكاو وفي أماكن أخرى بصورة غير رسميةفئة فرعية من: مقاطع صينية جزء من: الصينية التقليدية البلد: الصين, هونغ كونغ, ماكاو, تايوان, الفلبين, الولايات المتحدة, سنغافورة رمز العملة:  تاريخ التأسيس: ',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q9192',
#     'label': 'الصينية المندرينية',
#     'description': 'الصينية المندرينية فرعٌ من اللغة الصينية يتحدثها أغلب أهالي القسم الشمالي والشمالي الغربي من الصينفئة فرعية من: الصينية تقع في: هونغ كونغ, ماكاو البلد: بروناي, الصين, تايوان, إندونيسيا, ماليزيا, الفلبين, سنغافورة',
#     'ner_tag': 'MISC'}]},
#  {'word': 'طرب فاشن ',
#   'tag': 'MISC',
#   'sentence': 'دبي ـ شيرين الفايدي > ماذا تقولين عن فيلمك الأول « طرب فاشن » بعد عرضه في بيروت ودبي ؟ وأين لقيت تجاوب الجمهورمع  الفيلم أكثر ؟ ـ للأمانة عند عرض الفيلم في بيروت يوم 9 يوليو « تموز » الماضي ، لاقى استحساناً كبيراً .',
#   'word_index': 11,
#   'candidates': [{'entity': 'Q12221633',
#     'label': 'طرب فاشن',
#     'description': 'طرب فاشن فيلم أُصدر سنة 2006، من إخراج محمد دحام الشمري',
#     'ner_tag': 'MISC'}]},
#  {'word': 'تيني هاو ',
#   'tag': 'PERS',
#   'sentence': 'في عيد الملكة السماوية " تيني هاو " يسود إحساس بالروحانية ويختلط دخان البخور بالصور والأشباح .',
#   'word_index': 5,
#   'candidates': []},
#  {'word': 'كاترينا ',
#   'tag': 'MISC',
#   'sentence': 'الإعصار كاترينا حول أغلب مباني نيو أورليانز إلى أثر بعد عين ( رويترز - أرشيف ) يعرض اليوم الأربعاء للمرة الأولى فيلم للمخرج سبايك لي عن الإعصار كاترينا الذي دمر مدينة نيو أورليانز مدته أربع ساعات واسمه " انهيار الحواجز ترنيمة من أربعة فصول " أشبه بلائحة اتهام .',
#   'word_index': 27,
#   'candidates': [{'entity': 'Q18524243',
#     'label': 'كاترينا',
#     'description': 'كاترينا أسم مؤنث معطى (Kateřina)',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q1050684',
#     'label': 'كاترينا',
#     'description': 'كاترينا أسم مؤنث معطى (Caterina)',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q16277723',
#     'label': 'كاترينا',
#     'description': 'كاترينا أسم مؤنث معطى (Katrina)',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q20000499',
#     'label': 'كاترينا',
#     'description': 'كاترينا اسم مؤنث معطى (Katerina)',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q6377900',
#     'label': 'كاترينا',
#     'description': 'كاترينا فيلم جنوب إفريقي عام 1969',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q179718',
#     'label': 'كاترين الإسكندرانية',
#     'description': 'كاترين الإسكندرانية قديسة مسيحية عاشت في القرن الثالث الميلاديالمهنة: مبشر جزء من: مَلَكَ أُسَس',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q229190',
#     'label': 'كاترينا من سيينا',
#     'description': 'كاترينا من سيينا القديسة الإيطالية (1347-1380)المهنة: أُخْت, سياسي, فيلسوف, دبلوماسي, كاتب مذكرات, كاتب',
#     'ner_tag': 'PERS'}]},
#  {'word': 'البرازيل ',
#   'tag': 'LOC',
#   'sentence': 'عند مصب نهر اللؤلؤ أول ما يلفت أنظارنا ونحن نطل من الطائرة قبل هبوطها هو خليج  هونج كونج في النقطة الواقعة شرق مصب نهر اللؤلؤ والمرفا الذي يعتبر مع سان فرنسيسكو في أمريكا وريودي جانيرو في البرازيل أحد ثلاثة مواني ممتازة طبيعية في العالم ، وأعلن قائد الطائرة أن خليج  ويتليت بين جزيرة هونج كونج وكاولون يتسع بمساحة 59 كم2 ويتراوح عرضه بين كيلو متر ونصف وعشرة كيلو مترات ، وتدخل السفن الضخمة من خلال المجاري المائية الثلاثة إلى الخليج الذي يقع على امتداده 74 مرسى عميق الماء وتمتاز المواني بفعاليتها في العمل ، ونعرف أن ميناء  هونج كونج له أهمية في التجارة والمواصلات حيث يبط ما بين الشرق والغرب ومناطق جنوب شرق آسيا ، وتتردد عليه حوالي 120 ألف سفينة منها عشرون ألف سفينة عابرة للمحيطات ومائة ألف سفينة للمبلاحة النهرية سنويا ، ويمثل الميناء في خدمات النقل عن طريق الحاويات المرتبة الرابعة في العالم بعد نيويورك في أمريكا وروتردام في هولندا وكوبي في اليابان .',
#   'word_index': 36,
#   'candidates': [{'entity': 'Q155',
#     'label': 'البرازيل',
#     'description': 'البرازيل دولة في أمريكا الجنوبيةجزء من: أمريكا اللاتينية, الإيبيرية - الأمريكية, مخروط جنوبي, أمريكا الجنوبية البلد: الإمبراطورية البرتغالية, البرازيل تاريخ التأسيس: ',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q844135',
#     'label': 'البرازيل في الألعاب الأولمبية',
#     'description': 'البرازيل في الألعاب الأولمبية مشاركة الرياضيين من البرازيل في الألعاب الأولمبيةالبلد: البرازيل',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q25057',
#     'label': 'البرازيل (فيلم 1985)',
#     'description': 'البرازيل (فيلم 1985) فيلم أُصدر سنة 1985، من إخراج تيري غيليام',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q17329128',
#     'label': 'البرازيل ضد ألمانيا',
#     'description': 'البرازيل ضد ألمانيا نصف نهائي كأس العالم ٢٠١٤جزء من: مرحلة خروج المغلوب في كأس العالم 2014 البلد: البرازيل',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q899371',
#     'label': 'البرازيل (جزيرة أسطورية)',
#     'description': 'البرازيل (جزيرة أسطورية) جزيرة أس أس أس أس أس أس أس خر',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q17741814',
#     'label': 'البرازيل في الألعاب الأولمبية الصيفية 2016',
#     'description': 'البرازيل في الألعاب الأولمبية الصيفية 2016 وفود المناسبات الرياضيةالبلد: البرازيل',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q140422',
#     'label': 'البرازيل في الألعاب الأولمبية الصيفية 2012',
#     'description': 'البرازيل في الألعاب الأولمبية الصيفية 2012 وفود المناسبات الرياضيةالبلد: البرازيل',
#     'ner_tag': 'LOC'}]},
#  {'word': 'تشين ',
#   'tag': 'PERS',
#   'sentence': 'ومن أول وهلة , تجد نفسك أمام غابة من المروج الخضراء الجميلة التي تطل على بناء عربي إسلامي الطراز يشبه قباب الصوفيين المتناثرة في عدد من الدول العربية , والضريح ( القبة ) محاط بعدد كبير من القبور لمسلمين دُفنوا في عهود تاريخية مختلفة , وعند مدخل هذاالضريح  المهيب , كتب بلغة عربية جيدة ( روضة أبي وقاص ) , وتبدو غرفة الضريح من الداخل مربعة الشكل , حيث يتوسط الغرفة الضريح الغامض , المغطى بالحرير والمزخرف بالآيات القرآنية , ووضعت حوله كتب القرآن الكريم وغيرها من الكتب الإسلامية , وينتصب على جانبي الضريح نصب حجري كتب باللغة الصينية في حوالي القرن الثامن عشر في السنة السابعة من حكم الإمبراطور جاي شين من أسرة تشين , ويشير النصب إلى أن أربعين حكيماً من المدينة المنوّرة جاءوا إلى الصين في عهد أسرة تانغ , وذُبحوا أثناء تأديتهم لصلاة الجمعة على يد قطاع الطرق , وقد تم دفنهم في هذا المكان ) .',
#   'word_index': 114,
#   'candidates': [{'entity': 'Q16098027',
#     'label': 'كيم جونغ دي',
#     'description': 'كيم جونغ دي مغني كوري جنوبيالمهنة: مغني, ممثل, موسيقي, مغن مؤلف, راقص, عارض, ممثل تلفزيوني, كاتب أغاني, موسيقي تسجيلات',
#     'ner_tag': 'ORG'},
#    {'entity': 'Q5094616',
#     'label': 'تشين',
#     'description': 'تشين موسيقية أمريكيةالمهنة: مغني',
#     'ner_tag': 'ORG'},
#    {'entity': 'Q1352',
#     'label': 'تشيناي',
#     'description': 'تشيناي مدينة في جنوب الهند وعاصمة ولاية تاميل نادوتقع في: ضاحية تشيناي البلد: الهند, حكم الشركة في الهند, الراج البريطاني تاريخ التأسيس: ',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q170322',
#     'label': 'تشينغداو',
# ...
#     'ner_tag': 'LOC'}]},
#  {'word': 'الصين الشعبية ',
#   'tag': 'LOC',
#   'sentence': 'إنه سوق شامل في مبنى شاهق من عشرين طابقا ، وهو واحد من حوالي مائتين من العمارات المماثلة أقامتها الصين الشعبية في هونج كونج ، في هذه المجمعات تبيع الصين بأرخص الأسعار منتجات كلها من صناعاتها ومختلف فنونها من تحف ونحت وخزف وحرير منقوش وملابس وأزيا ومشغولات يدوية وصناعات حرفية وبضائع من كل نوع ، هذه المجمعات تجتذب السائحين الذين تستهدف الصن أن تعرض عليهم منتجاتها ليروا ما بلغته في مجالات التصنيع والإنتاج وبأسعار تبدو زهيدة جدا ، وإن كان مجموع حصيلتها يتجاوز مليار دولار في السنة ، وهي ينبوع من العملات الصعبة يتدفق عليها عن طريق هونج كونج .',
#   'word_index': 19,
#   'candidates': [{'entity': 'Q148',
#     'label': 'الصين',
#     'description': 'الصين دولة في شرق آسياجزء من: الصين التاريخية, شرق آسيا البلد: الصين تاريخ التأسيس: ',
#     'ner_tag': 'LOC'}]},
#  {'word': 'والعراق ',
#   'tag': 'LOC',
#   'sentence': 'القطن ، والثروة الحيوانية . ولهذا الغرض فإن منطقة سراخس تقع في نقطة الالتقاء بين هذه الدول ، وللوصول إلى الخليج والعراق وأوربا افتتح في مايو 1996 خط سكة حديد يربط ميناء " بندر عباس " الخليجي بمنطقة  سراخس .',
#   'word_index': 21,
#   'candidates': [{'entity': 'Q796',
#     'label': 'العراق',
#     'description': 'العراق دولة في غرب آسياجزء من: الشرق الأوسط, غرب آسيا البلد: العراق تاريخ التأسيس: ',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q2443729',
#     'label': 'القوة الجوية العراقية',
#     'description': 'القوة الجوية العراقية القوات الجوية في العراقجزء من: القوات المسلحة العراقية البلد: العراق تاريخ التأسيس: ',
#     'ner_tag': 'ORG'},
#    {'entity': 'Q15761734',
#     'label': 'العراق العراق',
#     'description': 'العراق العراق مجلة الدراسات الثقافية',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q545449',
#     'label': 'حرب العراق',
#     'description': 'حرب العراق استمرار صراعات قوات التحالف بقيادة الولايات المتحدة الأمريكية بعد إحتلال وعزو العراق وسقوط بغداد 2003جزء من: صراع العراق, الحرب الأمريكية على الإرهاب',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q37643',
#     'label': 'حرب الخليج الثانية',
#     'description': 'حرب الخليج الثانية حرب شنتها قوات التحالف بقيادة الولايات المتحدة الأمريكية ضد العراق لتحرير الكويتلديه جزء: عملية درع الصحراء, أولاً - حالة الطوارئ',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q27716130',
#     'label': 'العراق (1977)',
#     'description': 'العراق (1977) عدد المجلات؛ صحيفة الكردية',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q205047',
#     'label': 'إقليم كردستان العراق',
#     'description': 'إقليم كردستان العراق إقليم فدرالي شمال جمهورية العراقجزء من: العراق البلد: العراق تاريخ التأسيس: ',
#     'ner_tag': 'ORG'}]},
#  {'word': 'وافغانستان ',
#   'tag': 'LOC',
#   'sentence': 'أما نائب محافظ خراسان للشؤون السياحية والاجتماعية السيد فريدون بامتد فأنه يقول إن موقع المحافظة وحدودها المشتركة مع دول مثل تركمنستان وافغانستان جعلها ممراً طبيعياً لصادرات هذه الدول للعالم .',
#   'word_index': 21,
#   'candidates': [{'entity': 'Q889',
#     'label': 'أفغانستان',
#     'description': 'أفغانستان دولة في آسيا الوسطىالبلد: أفغانستان تاريخ التأسيس: , , , , , , , , , , ',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q509427',
#     'label': 'أفغانستان في الألعاب الأولمبية',
#     'description': 'أفغانستان في الألعاب الأولمبية للرياضيين القادمين من أفغانستان في دورة الألعاب الأولمبيةالبلد: أفغانستان',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q20113516',
#     'label': 'أفغانستان في الألعاب الأولمبية الصيفية 2016',
#     'description': 'أفغانستان في الألعاب الأولمبية الصيفية 2016 وفود المناسبات الرياضيةالبلد: أفغانستان',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q140225',
#     'label': 'أفغانستان في الألعاب الأولمبية الصيفية 2012',
#     'description': 'أفغانستان في الألعاب الأولمبية الصيفية 2012 وفود المناسبات الرياضيةالبلد: أفغانستان',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q42914216',
#     'label': 'أفغانستان في الألعاب الأولمبية الصيفية 2020',
#     'description': 'أفغانستان في الألعاب الأولمبية الصيفية 2020 أفغانستان في دورة الألعاب الأولمبيّة في طوكيو 2020تقع في: طوكيو البلد: أفغانستان',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q146395',
#     'label': 'أفغانستان في الألعاب الأولمبية الصيفية 2008',
#     'description': 'أفغانستان في الألعاب الأولمبية الصيفية 2008 وفود المناسبات الرياضيةالبلد: أفغانستان',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q146564',
#     'label': 'أفغانستان في الألعاب الأولمبية الصيفية 2004',
#     'description': 'أفغانستان في الألعاب الأولمبية الصيفية 2004 وفود المناسبات الرياضيةالبلد: أفغانستان',
#     'ner_tag': 'LOC'}]},
#  {'word': 'سيد محمد خاتمي ',
#   'tag': 'PERS',
#   'sentence': '. من الفكر ، وحتى الاقتصاد . كل مرة أزور فيها العاصمة الإيرانية طهران أجدها مختلفة عن الزيارة الأخرى ، وهي دائما تكون لنا محطة انطلاق ، هذه المرة كانت أكثر من محطة انطلاق ونحن نعد لزيارة محافظة  خراسان حيث مدينة  مشهد المقدسة ، لقد كانت ظروف العاصمة تحتم علينا التوقف أكثر من المطلوب ، حيث كان الاحتفال بمعرض  طهران الدولي للكتاب وكذلك احتفال العاصمة بمرور عام على انتخاب الرئيس الإيراني الدكتور سيد محمد خاتمي .',
#   'word_index': 72,
#   'candidates': [{'entity': 'Q180795',
#     'label': 'محمد خاتمي',
#     'description': 'محمد خاتمي سياسي شهير إصلاحي، فقيه شيعي، مؤلف ومثقف إيرانيالمهنة: عالِم, سياسي, أمين مكتبة, كاتب, شريك منتدى دولي, عسكري',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q13468575',
#     'label': 'القالب: محمد الخطي',
#     'description': 'القالب: محمد الخطي قالب ويكيميديا',
#     'ner_tag': 'PERS'}]},
#  {'word': 'مجلس الأمن ',
#   'tag': 'ORG',
#   'sentence': 'وقال فوزي صلوخ وزير الخارجية اللبنانية ـ عقب اجتماعه أمس مع الموفدين الدوليين ـ إن الموفدين أكدوا له أنه إذا تكررت الانتهاكات فسوف يصبح من مسئولية مجلس الأمن أن يتحرك , ويطالب إسرائيل بالتوقف عن مثل هذه الأعمال .',
#   'word_index': 26,
#   'candidates': [{'entity': 'Q37470',
#     'label': 'مجلس الأمن التابع للأمم المتحدة',
#     'description': 'مجلس الأمن التابع للأمم المتحدة مجلس أمن حكوميلديه جزء: عضو مجلس الأمن التابع للأمم المتحدة, رئيس مجلس الأمن التابع للأمم المتحدة جزء من: منظومة الأمم المتحدة, الأمم المتحدة تاريخ التأسيس:  موقع المقر: مقر الأمم المتحدة',
#     'ner_tag': 'ORG'},
#    {'entity': 'Q23764150',
#     'label': 'مجلس الأمن',
#     'description': 'مجلس الأمن جهاز الأمن الداخلي المنظم على الخطوط العسكرية للاتحاد الروسيالبلد: روسيا تاريخ التأسيس:  موقع المقر: موسكو, 2 - شارع كراسنوك',
#     'ner_tag': 'ORG'},
#    {'entity': 'Q672108',
#     'label': 'مجلس الأمن',
#     'description': 'مجلس الأمن إحدى مؤسسات الحكومة الروسيةفئة فرعية من: هيئة استشارية البلد: روسيا تاريخ التأسيس:  موقع المقر: مجلس شيوخ الكرملين, موسكو',
#     'ner_tag': 'ORG'},
#    {'entity': 'Q188628',
#     'label': 'مجلس إدارة',
#     'description': 'مجلس إدارة هيئة إدارية للمؤسسات والشركاتفئة فرعية من: حلقة نقاش, هيئة إدارية, منصب لديه جزء: عضو مجلس إدارة',
#     'ner_tag': None},
#    {'entity': 'Q851756',
#     'label': 'مجلس الأمن القومي الأمريكي',
#     'description': 'مجلس الأمن القومي الأمريكي منتدى الأمن الوطني والاستخبارات في الولايات المتحدة الأمريكيةفئة فرعية من: مؤسسة حكومية البلد: الولايات المتحدة تاريخ التأسيس:  موقع المقر: مبنى المكتب التنفيذي key people: مدير الاستخبارات الوطنية, مستشار الأمن القومي الأمريكي, وزير الدفاع الأمريكي, وزير الخارجية الأمريكي, رئيس الولايات المتحدة, نائب رئيس الولايات المتحدة, رئيس هيئة الأركان المشتركة الأمريكية, مكتب السياسة الوطنية لمكافحة المخدرات, وزير الطاقة في الولايات المتحدة, وزير الخزانة الأمريكي, نائب مستشار الأمن القومي, مستشار الأمن الداخلي, نائب عام الولايات المتحدة, رئيس موظفي البيت الأبيض, وزير الأمن الداخلي في الولايات المتحدة, مدير وكالة المخابرات المركزية, مستشار البيت الأبيض, المجلس الاقتصادي الوطني للولايات المتحدة, مندوب الولايات المتحدة الدائم لدى الأمم المتحدة, مدير مكتب الإدارة والميزانية',
#     'ner_tag': 'ORG'},
#    {'entity': 'Q1688469',
#     'label': 'مجلس الأمن التركي',
#     'description': 'مجلس الأمن التركي هيئة تنسيق أمني في تركياالبلد: تركيا تاريخ التأسيس:  موقع المقر: القصر الرئاسي بتركيا',
#     'ner_tag': 'ORG'},
#    {'entity': 'Q1063681',
#     'label': 'مجلس الأمن القومي (اليابان)',
#     'description': 'مجلس الأمن القومي (اليابان) في حكومة اليابانالبلد: اليابان تاريخ التأسيس: ',
#     'ner_tag': 'ORG'}]},
#  {'word': 'بوابة فاطمة ',
#   'tag': 'LOC',
#   'sentence': 'وفي هذه الأثناء , وصل اللواء العاشر في الجيش اللبناني أمس إلي بوابة فاطمة في بلدة  كفر كلا علي الحدود مع إسرائيل .',
#   'word_index': 12,
#   'candidates': [{'entity': 'Q2071881',
#     'label': 'بوابة فاطمة',
#     'description': 'بوابة فاطمة الحدود الحدودية بين لبنان وإسرائيلجزء من: حدود لبنان – إسرائيل البلد: لبنان, إسرائيل تاريخ التأسيس: ',
#     'ner_tag': 'PERS'}]},
#  {'word': 'الحنين ',
#   'tag': 'LOC',
#   'sentence': 'مَن بنى الحنين ومتى ? استرجعنا ونحن نتأمل هذا الأثر العربي العظيم كل ما قرأنا واطلعنا عليه في المصادر الصينية والعربية والغربية حول تاريخ هذا الصرح الأثري المهم , حيث يتفق الكثير من المؤرخين على أن المسجد قد تم بناؤه في وقت ما في أسرة تانغ , إلا إنهم يختلفون حول الباني , حيث تشير بعض الكتابات الصينية لمؤرخين مسلمين وغير مسلمين إلى أن باني المسجد هو الصحابي الجليل سعد ابن أبي وقاص الذي جاء في أول بعثة إسلامية إلى الصين إبان حياة الرسول الكريم .',
#   'word_index': 2,
#   'candidates': [{'entity': 'Q1595931',
#     'label': 'الحنين إلى الوطن',
#     'description': 'الحنين إلى الوطن وصف نفسي لحالة شخص يبعد عن وطنه أو عائلته لمدة من الزمن.فئة فرعية من: اضطراب الإحكام جزء من: مصطلحات علم النفس',
#     'ner_tag': 'ORG'},
#    {'entity': 'Q19453473',
#     'label': 'الحنــين',
#     'description': 'الحنــين قصيدة من تأليف إبراهيم ناجي',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q514694',
#     'label': 'الحنين إلى كاتالونيا',
#     'description': 'الحنين إلى كاتالونيا كتاب من تأليف جورج أورويل',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q1138968',
#     'label': 'الحنين للماضي (فيلم 1983)',
#     'description': 'الحنين للماضي (فيلم 1983) فيلم أُصدر سنة 1983، من إخراج أندري تاركوفسكي',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q621761',
#     'label': 'الحنين إلى الاتحاد السوفيتي',
#     'description': 'الحنين إلى الاتحاد السوفيتي - - - - - -:فئة فرعية من: 1910s 1910s, العُقَقَر, 30/1930:, 19/1940:, 50/50s, منذ عام 1960:, 1970 منذ سبعي سبعينات, 1980 إلى 1980, تسعيـس, الشيوعية',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q19453479',
#     'label': 'الحنين والدموع',
#     'description': 'الحنين والدموع قصيدة من تأليف سيد قطب',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q19453476',
#     'label': 'الحنين الى الجزيرة',
#     'description': 'الحنين الى الجزيرة قصيدة من تأليف مصطفى وهبي التل',
#     'ner_tag': 'LOC'}]},
#  {'word': 'وجيولونج ',
#   'tag': 'LOC',
#   'sentence': 'ففي سبتمبر 1984 توصلت بريطانيا والصين الشعبية إلى اتفاق حول مستقبل مستعمرة  هونج كونج ، وسيتولى حكام الصين الشيوعيون في بكين زمام الأمور في المقاطعة التي يصل عدد سكانها إلى خمسة ملايين ونصف مليون نسمة 98% منهم صينيون ، وتبلغ مساحتها 1064 كيلو مترا مربعا مقسمة بين جزيرة  هونج كونج بمساحة 75 كم 2 وجيولونج ( كاولون ) بمساحة 11 كم 2 ، وشينجيه ( الأرض الجديدة ) بمساحة 975 كم 2 ، بما فيها 320 جزيرة صغيرة محيطة بها .',
#   'word_index': 54,
#   'candidates': [{'entity': 'Q10879691',
#     'label': 'جيولونغ',
#     'description': 'جيولونغ الوصف لم يُعثرتقع في: مقاطعة يويشي البلد: الصين',
#     'ner_tag': 'LOC'}]},
#  {'word': 'فايز ',
#   'tag': 'PERS',
#   'sentence': 'عرضت الدور على فايز السعيد ، لكن فايز ، ربنا يزيده ، « مش فاضي » ، وهو مشغول بالأغاني الخاصة .',
#   'word_index': 7,
#   'candidates': [{'entity': 'Q123147141',
#     'label': 'فايز',
#     'description': 'فايز اسم مذكر معطى',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q206921',
#     'label': 'فايزر',
#     'description': 'فايزر شركة عالمية لتصنيع الأدويةجزء من: إس و بي 500, مؤشر داو جونز الصناعي,  البلد: الولايات المتحدة تاريخ التأسيس:  موقع المقر: نيويورك legal form: شركة ديلاوير, شركة عمومية محدودة key people: أ., ألبرت بورلا, و., سكوت غوتليب, هيلين هوبز, عدد الموظفين, جيمس م., دان دانتلمان, شانتانو ناراين, سوزان نورا جونسون, لِكِنْسِ, جيم/س., سوزان دزنيز, Echتفرات',
#     'ner_tag': 'ORG'},
#    {'entity': 'Q5431324',
#     'label': 'فائز',
#     'description': 'فائز اسم شخصي مذكر',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q21096945',
#     'label': 'فائز بجائزة',
#     'description': 'فائز بجائزة الشخص الذي حصل على جائزةفئة فرعية من: الفائز',
#     'ner_tag': None},
#    {'entity': 'Q20882747',
#     'label': 'فائز المرحلة',
#     'description': 'فائز المرحلة الدراج الذي فاز في المرحلة خلال سباق المرحلةفئة فرعية من: الفائز',
#     'ner_tag': None},
#    {'entity': 'Q502610',
#     'label': 'فايزماين',
#     'description': 'فايزماين بلدية ألمانياجزء من: Stimmkreis كروناتش، ليشتنFels تقع في: منطقة ليشتنفلز البلد: ألمانيا',
#     'ner_tag': 'LOC'},
#    {'entity': 'Q19631268',
#     'label': 'فايز زناد',
#     'description': 'فايز زناد طبيب قلب فرنسيالمهنة: طبيب قلب',
#     'ner_tag': 'PERS'}]},
#  {'word': 'رونالدينيو ',
#   'tag': 'PERS',
#   'sentence': 'ثم تحولت الأفضلية لبرشلونة في الشوط الثاني لكن نجميه رونالدينيو والأرجنتيني ميسي أضاعا فرصا لتعزيز الفوز خاصة مع تألق حارس إسبانيول غوركا ايريزوز .',
#   'word_index': 9,
#   'candidates': [{'entity': 'Q39444',
#     'label': 'رونالدينيو',
#     'description': 'رونالدينيو لاعب كرة قدم برازيليالمهنة: لاعب كرة قدم, سياسي',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q25692241',
#     'label': 'رونالدينيو يجدد لأتليتيكو مينيرو',
#     'description': 'رونالدينيو يجدد لأتليتيكو مينيرو مقالة ويكي أخبار',
#     'ner_tag': 'MISC'}]},
#  {'word': 'مينغ ',
#   'tag': 'PERS',
#   'sentence': 'ونعتقد أن تجاراً عرباً مسلمين مقيمين في الصين نظموا ومهّدوا لهذه الزيارة , حيث لم تنقطع منذ ذلك التاريخ وفود العرب إلى البلاط الصيني , كما استمر سيل التجار والدعاة الذين انتشروا في مدن وموانئ الصين المهمة حيث نظموا لهم جاليات كبيرة في مدن قوانغتشو وتشواتشو وخانجو ويانجو وغيرها , وقد استمر توافد العرب والمسلمين دعاة وتجاراً وسياسيين إلى الصين حتى بداية أسرة مينغ ( 1368 - 1644م ) عندما انعزلت الصين وانكفأت على نفسها .',
#   'word_index': 63,
#   'candidates': [{'entity': 'Q6716151',
#     'label': 'مينغ',
#     'description': 'مينغ منتجة تسجيلات أمريكا اللاتينية، وكاتبة أغنية، وDJالمهنة: منتج أسطوانات, ملحن',
#     'ner_tag': 'MISC'},
#    {'entity': 'Q254205',
#     'label': 'مينغ نا ون',
#     'description': 'مينغ نا ون الممثلة والنموذج الأمريكيانالمهنة: ممثل تلفزيوني, ممثل أفلام, مؤدي أصوات',
#     'ner_tag': 'ORG'},
#    {'entity': 'Q516301',
#     'label': 'مينغكوفين',
#     'description': 'مينغكوفين بلدية ألمانية في ولاية بافارياجزء من: Sstemkreis Dingulforing تقع في: منطقة دينغولفينغ-لاندآو البلد: ألمانيا',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q1198163',
#     'label': 'مينغ الجنوبية',
#     'description': 'مينغ الجنوبية المولداتجزء من: الإمبراطورية الصينية الأخيرة تاريخ التأسيس: ',
#     'ner_tag': 'ORG'},
#    {'entity': 'Q230932',
#     'label': 'مينجا تشيفير',
#     'description': 'مينجا تشيفير مدينة في أذربيجانتقع في: أذربيجان, جمهورية أذربيجان الاشتراكية السوفيتية البلد: أذربيجان تاريخ التأسيس: ',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q11775',
#     'label': 'مينغ س. لين',
#     'description': 'مينغ س. لين عالمة حاسوب أمريكيةالمهنة: عالم حاسوب, مهندس, باحث',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q9126923',
#     'label': 'مينغ هونغواي',
#     'description': 'مينغ هونغواي سياسي صينيالمهنة: سياسي, ضابط شرطة',
#     'ner_tag': 'PERS'}]},
#  {'word': 'ميساء مغربي ',
#   'tag': 'PERS',
#   'sentence': 'من فتاة شاركت كموديل في « فيديو كليب » مع الفنانين وليد توفيق وفايز السعيد ، إلى ممثلة تختلف حولها الآراء لدى تقييم مشاركتها في الدراما الخليجية ، وإلى منتجة مغامرة لأول فيلم سينمائي خليجي « طرب فاشن » ، استطاعت ميساء مغربي أن تُحوّل أحلامها الصغيرة إلى آمال كبيرة ، وأن تحظى بالنجومية واستقطاب الأضواء .',
#   'word_index': 41,
#   'candidates': [{'entity': 'Q12246783',
#     'label': 'ميساء مغربي',
#     'description': 'ميساء مغربي ممثلة مغربيةالمهنة: ممثل, ممثل أفلام',
#     'ner_tag': 'PERS'}]},
#  {'word': 'دام تي ',
#   'tag': 'PERS',
#   'sentence': 'وتنتمي دام تي إلى حركة الملوك التي نشأت في خمسينيات القرن التاسع عشر , وكانت هي سادسة ملوكها .',
#   'word_index': 1,
#   'candidates': []},
#  {'word': 'متحف قوانغتشو ',
#   'tag': 'LOC',
#   'sentence': 'وجود عربي وإسلامي بهذا الثقل والكثافة في مدينة قوانغتشو , كان لابد أن يترك بصماته وآثاره في المقتنيات التي ضمتها جدران متحف قوانغتشو .',
#   'word_index': 21,
#   'candidates': [{'entity': 'Q30941307',
#     'label': 'متحف Sucho',
#     'description': 'متحف Sucho في غوانغتشو، الصينتقع في: يويكسيو البلد: الصين',
#     'ner_tag': 'PERS'},
#    {'entity': 'Q25378279',
#     'label': 'متحف الفنون',
#     'description': 'متحف الفنون الوصف لم يُعثرتقع في: مقاطعة تشيغانغ, مقاطعة هونغ - قياو البلد: الصين تاريخ التأسيس: ',
#     'ner_tag': 'ORG'}]}]

# %%
subset_filtered_train_data[5]
# Out:
# {'word': 'قرية بوادي ',
#  'tag': 'ORG',
#  'sentence': 'وأضاف الحزب أن القوة الإسرائيلية المهاجمة حاولت السيطرة علي مدرسة قرية بوادي , ونفي المتحدث الأنباء التي ترددت عن مقتل3  من الحزب في الاشتباكات .',
#  'word_index': 10,
#  'candidates': []}

# %%
with open("subset_filtered_train_data.json", "w", encoding='utf-8') as f:
    json.dump(subset_filtered_train_data, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ## Generating embedding

# %%
model_name = "aubmindlab/bert-base-arabertv02"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)

# %%
for entry in subset_filtered_train_data:
    word = entry['word']
    sentence = entry['sentence']
    sentence_embedding = generate_contextual_embeddings(sentence)
    entry['sentence_embedding'] = sentence_embedding
    candidates = entry['candidates']

    # Embedding for word
    word_embedding = get_word_embeddings_arabert(word,sentence)
    entry['word_embedding'] = word_embedding
    # Embedding for each candidate's label and description if not empty
    for candidate in candidates:
        label = candidate['label']
        description = candidate['description']

        # Embedding for candidate label
        if label != '':
            label_embedding = get_word_embeddings_arabert(label,description)
            candidate['label_embedding'] = label_embedding

        # Embedding for candidate description
        if description != '':
            description_embedding = generate_contextual_embeddings(description)
            candidate['description_embedding'] = description_embedding

# %% [markdown]
# ## Disambiguation

# %%
result_entities = []
for entry in subset_filtered_train_data:
    best_entity = disambiguation_function([entry])
    result_entities.append(best_entity)


print(result_entities)
# Out:
# [[{'word': 'الصين ', 'sentence': 'كما يتحدثون أيضاً عن أحلام للإمبراطور ومشاهدات مسئول الفلك لنجم مضيء في اتجاه الغرب , يفسّره فلكيو القصر للإمبراطور آنذاك بأنه بشارة بظهور رجل حكيم في بلاد العرب هو محمد ( صلى الله عليه وسلم ) , فيرسل الإمبراطور وفداً للرسول الجديد احتراماً وتقرّباً , حيث يعود الوفد الصيني من رحلته إلى شبه الجزيرة العربية ومعه وفد عربي من صحابة الرسول وفي مقدمتهم الصحابي الجليل سعد بن أبي وقاص كأول دخول للإسلام في الصين , إلا أن هذه الأسطورة تشبه إلى حد كبير ما جاء في الأساطير البوذية حول دخول الديانة البوذية إلى الصين من الهند .', 'tag': 'LOC', 'correctly_labelled': 1, 'best_entity': {'entity': 'Q148', 'entity_label': 'الصين', 'entity_description': 'الصين دولة في شرق آسياجزء من: الصين التاريخية, شرق آسيا البلد: الصين تاريخ التأسيس: ', 'tag': 'LOC', 'label': 1}, 'other_entities': [{'entity': 'Q148', 'entity_label': 'الصين', 'entity_description': 'الصين دولة في شرق آسياجزء من: الصين التاريخية, شرق آسيا البلد: الصين تاريخ التأسيس: ', 'tag': 'LOC', 'label': 0}, {'entity': 'Q29520', 'entity_label': 'الصين التاريخية', 'entity_description': 'الصين التاريخية في المنطقة الثقافية، والحضارة القديمة، والأمة في شرق آسيا، تشير في معظمها إلى جمهورية الصين الشعبية في الحالة السياسية ونادراً ما تشير إلى جمهورية الصينلديه جزء: الصين, تايوان', 'tag': 'LOC', 'label': 0}, {'entity': 'Q1135255', 'entity_label': 'جمهورية الصين السوفيتية', 'entity_description': 'جمهورية الصين السوفيتية دولة سابقةتاريخ التأسيس: ', 'tag': 'LOC', 'label': 0}, {'entity': 'Q20420088', 'entity_label': 'الصين', 'entity_description': 'الصين محلة في قرية العارضة، عزلة بني شبيب، مديرية حبيش، محافظة إب اليمنيةتقع في: العارضة البلد: اليمن', 'tag': 'LOC', 'label': 0}, {'entity': 'Q7850', 'entity_label': 'الصينية', 'entity_description': 'الصينية مجموعة اللغات التي تنتمي إلى الأسرة الصينية التبتيةفئة فرعية من: لغات صينية تبتية, م لديه جزء: لغات مين الصينية, صينية يوي, لغة الهاكا, وو, الصينية المندرينية, شيانغ صيني, جين صيني, Huechs الصينية, البنغية, با - سو صيني, شاسوتشو البلد: الصين, تايوان', 'tag': 'MISC', 'label': 0}, {'entity': 'Q178528', 'entity_label': 'حروف صينية تقليدية', 'entity_description': 'حروف صينية تقليدية رموز صينية لا تزال تستخدم لأغراض رسمية في تايوان وفي هونغ كونغ وماكاو وفي أماكن أخرى بصورة غير رسميةفئة فرعية من: مقاطع صينية جزء من: الصينية التقليدية البلد: الصين, هونغ كونغ, ماكاو, تايوان, الفلبين, الولايات المتحدة, سنغافورة رمز العملة:  تاريخ التأسيس: ', 'tag': 'MISC', 'label': 0}, {'entity': 'Q9192', 'entity_label': 'الصينية المندرينية', 'entity_description': 'الصينية المندرينية فرعٌ من اللغة الصينية يتحدثها أغلب أهالي القسم الشمالي والشمالي الغربي من الصينفئة فرعية من: الصينية تقع في: هونغ كونغ, ماكاو البلد: بروناي, الصين, تايوان, إندونيسيا, ماليزيا, الفلبين, سنغافورة', 'tag': 'MISC', 'label': 0}]}], [{'word': 'سعد ابن أبي وقاص ', 'sentence': 'المصادر العربية - كما يعرف القارئ - واضحة جداً حول هذا الموضوع , فالصحابي الجليل سعد ابن أبي وقاص - كما أشرنا - مدفون في المدينة المنورة , كما أن المراجع التاريخية العربية لم تشر لأي زيارة له للصين , إلا أن المصادر التاريخية الإسلامية وغير الإسلامية الصينية بدأت في حقيقة الأمر منذ حوالي القرن الرابع عشر وحتى السابع عشر تؤكد باستمرار أن رجلاً يدعى سعد وقاص وأحياناً وانغ قاص قد زار الصين في القرن السابع الميلادي ( الأول الهجري ) ودُفن في مدينة قوانغتشو .', 'tag': 'PERS', 'correctly_labelled': 1, 'best_entity': {'entity': 'Q380184', 'entity_label': 'سعد بن أبي وقاص', 'entity_description': 'سعد بن أبي وقاص صحابي وقائد مسلم وأحد العشرة المبشرين بالجنة عند المسلمين السنةالمهنة: تاجر, قائد عسكري جزء من: صحابة', 'tag': 'PERS', 'label': 1}, 'other_entities': [{'entity': 'Q380184', 'entity_label': 'سعد بن أبي وقاص', 'entity_description': 'سعد بن أبي وقاص صحابي وقائد مسلم وأحد العشرة المبشرين بالجنة عند المسلمين السنةالمهنة: تاجر, قائد عسكري جزء من: صحابة', 'tag': 'PERS', 'label': 0}]}], [{'word': 'محمد خاتمي ', 'sentence': 'كما أن انهيار اسعار النفط سيعني أن يهبط دخل إيران إلى عشرة بلايين دولار هذه السنة من 16 بليوناً سنة 1996 ، وسيعني بالتالي أن مشاريع كثيرة وإصلاحات ستطوى مما سيفقد العهد الجديد كثيرا من شعبيته ...

# %%
with open("entities.json", "w", encoding='utf-8') as f:
    json.dump(result_entities, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ## Training AraBERT

# %%
import json
from sklearn.preprocessing import LabelEncoder
from transformers import AutoTokenizer, AutoModel
# from preprocess import NEVER_SPLIT_TOKENS,ArabertPreprocessor
from arabert.preprocess import NEVER_SPLIT_TOKENS,ArabertPreprocessor
from farasa.segmenter import FarasaSegmenter
import torch
import requests
from transformers import MBartForConditionalGeneration, MBart50Tokenizer
from transformers import AutoModelForTokenClassification
import re
from collections import defaultdict
from sklearn.metrics.pairwise import cosine_similarity
from pyarabic.araby import tokenize
from transformers import MarianMTModel, MarianTokenizer
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
import torch.nn.functional as F
import numpy as np
import spacy
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score


from google.colab import drive

drive.mount('/content/drive')

data_path = '/content/drive/MyDrive/dataset.json'
with open(data_path, 'r', encoding='utf-8') as file:
            dataset = json.load(file)

# %%
class MultiCandidateBinaryClassificationDataset(Dataset):
    def __init__(self, data, tokenizer, max_length=128):
        self.data = data
        self.tokenizer = tokenizer
        self.max_length = max_length
        self.examples = self.prepare_examples()

    def __len__(self):
        return len(self.examples)

    def prepare_examples(self):
        examples = []
        for item in self.data:
            word = item['word']
            sentence = item['sentence']
            candidates = item['candidates']
            ner_tag=item['tag']

            for candidate in candidates:
                entity_text = candidate['entity_description']
                entity_ID = candidate['entity']
                label = candidate['label']
                entity_label=candidate['entity_label']

                text = f"{word} {sentence} [SEP] {entity_label} {entity_text}"

                inputs = self.tokenizer.encode_plus(
                    text,
                    max_length=self.max_length,
                    padding='max_length',
                    truncation=True,
                    return_tensors='pt'
                )

                examples.append({
                    'input_ids': inputs['input_ids'].squeeze(),
                    'attention_mask': inputs['attention_mask'].squeeze(),
                    'label': torch.tensor(label, dtype=torch.float),
                    'word': word,
                    'sentence': sentence,
                    'entity_ID':entity_ID,
                    'entity_label': entity_label,
                    'entity_description':entity_text,
                    'tag':ner_tag
                })

        return examples

    def __getitem__(self, idx):
        return self.examples[idx]

# %%
class FineTunedAraBERTForMultiCandidateBinaryClassification(nn.Module):
    def __init__(self, arabert_model_name):
        super(FineTunedAraBERTForMultiCandidateBinaryClassification, self).__init__()
        self.arabert = AutoModel.from_pretrained(arabert_model_name)
        self.dropout = nn.Dropout(0.1)
        self.classifier = nn.Linear(self.arabert.config.hidden_size, 1)

    def forward(self, input_ids, attention_mask):
        outputs = self.arabert(input_ids=input_ids, attention_mask=attention_mask)
        pooled_output = outputs.last_hidden_state[:, 0, :]  # [CLS] token
        pooled_output = self.dropout(pooled_output)
        logits = self.classifier(pooled_output)
        return logits.squeeze(-1)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')


arabert_model_name = "aubmindlab/bert-base-arabertv02"
tokenizer = AutoTokenizer.from_pretrained(arabert_model_name)
model = FineTunedAraBERTForMultiCandidateBinaryClassification(arabert_model_name="aubmindlab/bert-base-arabertv02").to(device)
multi_candidate_binary_dataset = MultiCandidateBinaryClassificationDataset(data=dataset, tokenizer=tokenizer)

# %%
from sklearn.model_selection import train_test_split

optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
criterion = nn.BCEWithLogitsLoss()
batch_size = 8  # Set your desired batch size
multi_candidate_binary_dataloader = DataLoader(multi_candidate_binary_dataset, batch_size=batch_size, shuffle=True)
num_epochs = 2


validation_size = 0.15
test_size = 0.15

remaining, test_data = train_test_split(multi_candidate_binary_dataset, test_size=test_size, random_state=42)

train_data, validation_data = train_test_split(remaining, test_size=validation_size, random_state=42)

train_dataloader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
validation_dataloader = DataLoader(validation_data, batch_size=batch_size, shuffle=False)
test_dataloader = DataLoader(test_data, batch_size=batch_size, shuffle=False)

# %%
epsilon = 1e-7

for epoch in range(num_epochs):
    print(f"Epoch {epoch + 1}/{num_epochs}")
    model.train()
    total_loss = 0

    for batch in multi_candidate_binary_dataloader:
        inputs = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['label'].to(torch.float).to(device)

        # Normalize labels to be between 0 and 1
        max_label_value = torch.max(labels)
        labels_normalized = labels / (max_label_value + epsilon)  # Add epsilon to avoid division by zero

        optimizer.zero_grad()
        logits = model(input_ids=inputs, attention_mask=attention_mask)
        probabilities = torch.sigmoid(logits)
        loss = F.binary_cross_entropy(probabilities, labels_normalized)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    avg_loss = total_loss / len(multi_candidate_binary_dataloader)
    print(f"Epoch {epoch + 1}/{num_epochs} - Average Loss: {avg_loss:.4f}")

    # Validation after each epoch
    accuracy, precision, recall, f1 = validate(model, validation_dataloader)
    print(f"Epoch {epoch + 1}/{num_epochs} - Validation Metrics:")
    print(f"Accuracy: {accuracy:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, F1-score: {f1:.4f}")

    # Evaluation on test set after each epoch
    test_accuracy, test_precision, test_recall, test_f1 = validate(model, test_dataloader)
    print("Evaluation Metrics on Test Set:")
    print(f"Accuracy: {test_accuracy:.4f}, Precision: {test_precision:.4f}, Recall: {test_recall:.4f}, F1-score: {test_f1:.4f}")

# %%
def validate(model, dataloader):
    model.eval()
    val_labels = []
    val_predictions = []

    with torch.no_grad():
        for batch in dataloader:
            inputs = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['label'].to(torch.float).to(device)

            logits = model(input_ids=inputs, attention_mask=attention_mask)
            probabilities = torch.sigmoid(logits)
            predicted_labels = (probabilities > 0.5).float()  # Threshold at 0.5

            val_labels.extend(labels.cpu().numpy())
            val_predictions.extend(predicted_labels.cpu().numpy())

    val_labels = np.array(val_labels)
    val_predictions = np.array(val_predictions)

    accuracy = accuracy_score(val_labels, val_predictions)
    precision, recall, f1, _ = precision_recall_fscore_support(val_labels, val_predictions, average='weighted')

    return accuracy, precision, recall, f1

# %%
def display_predictions_structured(model, dataloader, tokenizer, output_file):
    predictions_data = []

    model.eval()
    with torch.no_grad():
        for batch in dataloader:
            inputs = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['label'].to(torch.float).to(device)
            words = batch['word']
            sentences = batch['sentence']
            entity_ids = batch['entity_ID']
            entity_labels = batch['entity_label']
            entity_descriptions = batch['entity_description']
            ner_tags = batch['tag']

            logits = model(input_ids=inputs, attention_mask=attention_mask)
            probabilities = torch.sigmoid(logits)
            predicted_labels = (probabilities > 0.5).float()  # Threshold at 0.5

            for idx in range(len(inputs)):
                word = words[idx]
                sentence = sentences[idx]
                entity_id = entity_ids[idx]
                input_text = tokenizer.decode(inputs[idx], skip_special_tokens=True)
                prediction = "True" if predicted_labels[idx] == 1 else "False"
                entity_label = entity_labels[idx]
                entity_description = entity_descriptions[idx]
                ner_tag = ner_tags[idx]

                prediction_info = {
                    "Word": word,
                    "Sentence": sentence,
                    "Entity_ID": entity_id,
                    "Predicted_Label": prediction,
                    "Entity_Label": entity_label,
                    "Entity_Description": entity_description,
                    "NER_Tag": ner_tag
                }

                # Append the prediction data to the list
                predictions_data.append(prediction_info)

    # Save the data to a JSON file
    with open(output_file, 'w') as outfile:
        json.dump(predictions_data, outfile, ensure_ascii=False, indent=4)

# %%
output_file = 'predictions_data.json'
display_predictions_structured(model, validation_dataloader, tokenizer, output_file)

# %% [markdown]
# ## Some adjustments

# %%
def get_entity_data_with_NER_from_json(json_path):
    with open(json_path, 'r', encoding='utf-8') as json_file:
        data = json.load(json_file)

    for entity_data in data:
        candidates = entity_data.get('candidates', [])
        entity_id = None
        word=entity_data['word']

        for candidate in candidates:
            if candidate.get('entity'):
                entity_id = candidate['entity']
                entity_desc = candidate['entity_description']
                entity_label= candidate['entity_label']

                break  # Stop after finding the first entity ID

        if entity_id:
            url = f"https://www.wikidata.org/wiki/Special:EntityData/{entity_id}.json"
            response = requests.get(url)
            entity_data_wikidata = response.json()

            if 'entities' in entity_data_wikidata and entity_id in entity_data_wikidata['entities']:
                entity_info = entity_data_wikidata['entities'][entity_id]
                claims = entity_info.get('claims', {})

                relevant_properties = {
                    'instance of': 'P31'
                    # Add more relevant properties if needed for further NER tag classification
                }

                instance_label = ''

                for prop_label, prop_id in relevant_properties.items():
                    if prop_id in claims and prop_label == 'instance of':
                        prop_values = [claim['mainsnak']['datavalue']['value']['id'] for claim in claims[prop_id]]
                        if 'Q5' in prop_values:  # Q5 represents human
                            instance_label = "PERS"
                        elif 'Q11424' in prop_values:  # Q11424 represents film
                            instance_label = "MISC"
                        elif 'Q2221906' in prop_values:  # Q2221906 represents geographical location
                            instance_label = "LOC"
                        elif 'Q4917' in prop_values:  # Q4917 represents currency
                            instance_label = "MISC"
                        elif 'Q43229' in prop_values:  # Q43229 represents organization
                            instance_label = "ORG"

                # Check if instance_label is still empty
                if not instance_label:
                    # Perform NER using spaCy for translated text
                    # Assuming you have the necessary setup for translate_to_english and map_spacy_labels functions
                    input_data = [{
                        'word': word,  # Assuming 'en' label exists
                        'candidates': [{
                            'label': entity_label,  # Assuming 'en' label exists
                            'description': entity_desc
                        }]
                    }]

                    # NER with translated text using spaCy
                    input_data_with_ner = ner_for_entities_with_candidates(input_data)
                    if input_data_with_ner and 'ner_tag' in input_data_with_ner[0]['candidates'][0]:
                        instance_label = input_data_with_ner[0]['candidates'][0]['ner_tag']

                # Update each candidate with the instance_label
                for candidate in candidates:
                    candidate['ner_tag'] = instance_label

                entity_data_wikidata['entities'][entity_id] = entity_info

            else:
                entity_data_wikidata['entities'][entity_id] = {
                    'entity_ID': entity_id,
                    'ner_tag': ''
                }

    with open(json_path, "w", encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=4)

# %%
fix='/content/drive/MyDrive/fix.json'
get_entity_data_with_NER_from_json(fix)

# %% [markdown]
# ## Saving Datasets and Models
